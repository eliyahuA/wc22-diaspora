# %%
'''
Fetches league information for each of the competitions
and saves as a single CSV, also updating the existing JSON files
in the process.
'''
# Out:
# '\nFetches league information for each of the competitions\nand saves as a single CSV, also updating the existing JSON files\nin the process.\n'

# %%
from bs4 import BeautifulSoup
from io import BytesIO
import glob
import json
import pandas as pd
from pprint import pprint
import requests
import re
from selenium import webdriver
from tqdm.notebook import tqdm
import time

# %%
HEADERS = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'
    }

# %%
def already_saved(league_id):
    '''
    Controls whether the data for this specific league
    was already saved properly. Returns true or false.
    
    Params:
    
    club_id -> string with the unique club id at Transfermarkt
    '''
    
        
    leagues = glob.glob("../output/leagues/*.json")
    leagues = list(map(lambda x: re.search("/leagues/(.+).json", x).group(1), leagues))

    return (league_id in leagues)

# %%
def fetch_leagues(pattern):
    '''
    Fetches all files with league information
    and keeps unique entries to scrape.
    
    Params:
    
    pattern -> str, a glob pattern
    '''
    
    league_files = glob.glob(pattern)
    
    dfs = []
    for file in league_files:
        with open(file, "r") as f:
            data = json.load(f)
            
        df = pd.DataFrame(data)
        dfs.append(df)
        
    dfs = pd.concat(dfs, ignore_index=True)
    
    dfs = dfs[['league_url', 'league_name', 'league_id']]
    dfs = dfs.drop_duplicates().reset_index(drop=True)
    
    return dfs

# %%
def save_json(data, outpath):
    '''
    Saves a JSON file in the specified output path
    '''
    with open(outpath, 'w+') as f:
        json.dump(data, f)

# %%
def get_league_info(league_url):
    '''
    Scrapes the relevant club information.
    
    Params:
    
    driver -> a selenium webdriver
    club_url -> part of the url for the transfermakt club page
    '''
    
    url = f"https://transfermarkt.com{league_url}"
    print(url)
    
    r = requests.get(url, headers=HEADERS)
    
    soup = BeautifulSoup(r.text)
    
    data = {}
    
    # Cup
    if 'pokalwettbewerb' in league_url:
        content = soup.find('div', class_='dataContent')
        data_value = content.find('span', class_='dataValue')
    
        country = data_value.find('img')
        if not country: 
            country = 'no country'
        else:
            country = country['alt'].strip()
            
        league_tier = data_value.text.strip()
        
        data['country'] = country
        data['league_tier'] = league_tier
        data['type'] = 'cup'
        
    # League
    elif 'wettbewerb' in league_url:
        
        box = soup.find("div", class_="data-header__box--big")
        country = box.find("span", class_="data-header__club").find('a').text.strip()
        league_tier = box.find("span", class_="data-header__label").find('span').text.strip()
        
        data['country'] = country
        data['league_tier'] = league_tier
        data['type'] = 'league'

   
    return data

# %%
def main():
    
    leagues_to_scrape = fetch_leagues("../output/players/league-info-*.json")
        
    for index, row in tqdm(leagues_to_scrape.iterrows(), total=leagues_to_scrape.shape[0]):
  
        league_url = row.league_url
        league_id = row.league_id
        league_name = row.league_name
        
        print(f"{league_id}, {league_name}")
        
        if already_saved(league_id):
            print('Already saved')
            print()
            continue
    
        data = get_league_info(league_url)
        data['league_url'] = league_url
        data['league_id'] = league_id
        data['league_name']= league_name
        
        pprint(data)

        with open(f"../output/leagues/{league_id}.json", "w+") as f:
            json.dump(data, f)
            
        print()

# %%
if __name__ == "__main__":
    main()
# Out:
#   0%|          | 0/489 [00:00<?, ?it/s]
# L1, Bundesliga
# Already saved
#
# CL, Champions League
# Already saved
#
# BJ3, U17-Bundesliga Süd/Südwest
# Already saved
#
# L3, 3. Liga
# Already saved
#
# AJ3, U19-BL S/SW
# Already saved
#
# DFB, DFB-Pokal
# Already saved
#
# DFL, DFL-Supercup
# Already saved
#
# GB18, U18 Premier League
# Already saved
#
# KLUB, Club World Cup
# Already saved
#
# 19YL, UEFA Youth League
# Already saved
#
# USC, UEFA Super Cup
# Already saved
#
# IT1, Serie A
# Already saved
#
# AR1N, Liga Profesional
# Already saved
#
# CIT, Italy Cup
# Already saved
#
# EL, Europa League
# Already saved
#
# CLI, Libertadores
# Already saved
#
# CS, Copa Sudamericana
# Already saved
#
# ARCA, Copa Argentina
# Already saved
#
# SCI, Supercoppa Italiana
# Already saved
#
# QSL, Stars League
# Already saved
#
# QEC1, Amir Cup
# Already saved
#
# QSCP, QSC
# Already saved
#
# GB1, Premier League
# Already saved
#
# NL1, Eredivisie
# Already saved
#
# PO1, Liga Portugal
# Already saved
#
# NLP, KNVB beker
# Already saved
#
# FAC, FA Cup
# Already saved
#
# CGB, EFL Cup
# Already saved
#
# CLQ, Champions League Qu.
# Already saved
#
# UEFA, UEFA Cup
# Already saved
#
# BE1, Jupiler Pro League
# Already saved
#
# POPO, Taça de Portugal
# Already saved
#
# PON2, Play-Offs Promotie/Deg.
# Already saved
#
# UCOL, Conference League
# Already saved
#
# POCP, Allianz Cup
# Already saved
#
# ELQ, Europa League Qualifying
# Already saved
#
# PONL, Play-Offs Conference League
# Already saved
#
# POSU, Supertaça
# Already saved
#
# GB21, Premier League 2
# Already saved
#
# PO2, Liga Sabseg
# Already saved
#
# PL1, Ekstraklasa
# Already saved
#
# MLS1, MLS
# Already saved
#
# POPU, Fortuna Polish Cup
# Already saved
#
# PTRL, Play-Off Liga Portugal Bwin
# Already saved
#
# MLSP, US Open Cup
# Already saved
#
# FR2, Ligue 2
# Already saved
#
# FR1, Ligue 1
# Already saved
#
# SA1, Saudi Pro League
# Already saved
#
# FR3, Championnat National
# Already saved
#
# FRC, Coupe de France
# Already saved
#
# FRL, Coupe de la Ligue
# Already saved
#
# SAKC, King's Cup
# Already saved
#
# CN2B, National 2 - Grp. B
# Already saved
#
# FRR1, Rel. Ligue 1
# Already saved
#
# PDV1, Primera División Clausura
# Already saved
#
# CRPD, Primera División Apertura
# Already saved
#
# TR1, Süper Lig
# Already saved
#
# TRP, Türkiye Kupasi
# Already saved
#
# CRPV, Apertura Play-Off
# Already saved
#
# COLE, CONCACAF League
# Already saved
#
# CIF, Apertura Finale
# Already saved
#
# PDV2, Clausura Play-Off
# Already saved
#
# PDRL, Primera Div. Rel.
# Already saved
#
# NLSC, Johan Cruijff Schaal
# Already saved
#
# SCCR, Supercopa de Costa Rica
# Already saved
#
# GB2, Championship
# Already saved
#
# FAYC, FA Youth Cup
# Already saved
#
# GBFL, EFL Trophy
# Already saved
#
# POCC, Championship Play-Offs
# Already saved
#
# 18GB, U18 PL - Final Stage
# Already saved
#
# 511, Derde Divisie Sunday
# Already saved
#
# MAR1, Botola Pro Inwi
# Already saved
#
# ACL, CAF-Champions League
# Already saved
#
# UAE1, UAE Pro League
# Already saved
#
# MARP, Coupe du Trône Marocaine
# Already saved
#
# CAFS, CAF-Supercup
# Already saved
#
# RLW3, Regionalliga West
# Already saved
#
# BJ2, U17-Bundesliga West
# Already saved
#
# AJ2, U19-Bundesliga West
# Already saved
#
# L1PO, Bundesliga Playoffs
# Already saved
#
# DFBJ, DFB-Pokal der Junioren
# Already saved
#
# URUC, Primera División Clausura
# Already saved
#
# URU1, Primera División Apertura
# Already saved
#
# URUI, Torneo Intermedio
# Already saved
#
# NLBE, Beloften Eredivisie
# Already saved
#
# URUP, Playoffs Primera Division
# Already saved
#
# NLBV, Beloften Preliminary Round
# Already saved
#
# URSC, Supercopa
# Already saved
#
# ES1, LaLiga
# Already saved
#
# ARGC, Torneo Final
# Already saved
#
# ARG1, Torneo Inicial
# Already saved
#
# CDR, Copa del Rey
# Already saved
#
# ECLQ, UECL Qualifiers
# Already saved
#
# JAP3, J3 League
# Already saved
#
# JAP1, J1 League
# Already saved
#
# JAPC, J. League Cup
# Already saved
#
# JEMP, Emperor's Cup
# Already saved
#
# IRN1, Persian Gulf Pro League
# Already saved
#
# AFCL, AFC Champions League
# Already saved
#
# IRNP, Hazfi Cup
# Already saved
#
# IRSC, Iran Super Cup
# Already saved
#
# QUC1, Qatar Cup
# Already saved
#
# USL, USLC
# Already saved
#
# CCL, CONCACAF Champions League
# Already saved
#
# POUS, MLS Cup Playoffs
# Already saved
#
# USLP, USLC Playoffs
# Already saved
#
# USSP, MLS is Back
# Already saved
#
# EJPL, JPL Playoff I
# Already saved
#
# CCB, Beker van Belgie
# Already saved
#
# RU1, Premier Liga
# Already saved
#
# NL2, Keuken Kampioen Divisie
# Already saved
#
# NLBJ, U17 Div. 1 Spring
# Already saved
#
# NLAJ, U19 Eredivisie
# Already saved
#
# NLVB, U17 Div. 1 Fall
# Already saved
#
# NLJV, Preliminary round U19 Eredivisie
# Already saved
#
# NLJB, U18 Cup Netherlands
# Already saved
#
# SC1, Premiership
# Already saved
#
# SFA, SFA Cup
# Already saved
#
# SCP, League Cup
# Already saved
#
# SCPA, Premiership Relegation
# Already saved
#
# SCPM, Scottish Premiership Top Six Split
# Already saved
#
# CAN, Canadian Championship
# Already saved
#
# CAMC, Campeones Cup
# Already saved
#
# GBR, Reserve League
# Already saved
#
# GBEG, U21 PL Elite Group
# Already saved
#
# GBCS, Community Shield
# Already saved
#
# ES3C, 2ª B - Grupo III
# Already saved
#
# KR1, SuperSport HNL
# Already saved
#
# L2, 2. Bundesliga
# Already saved
#
# KR2, Prva NL
# Already saved
#
# KRC, Hrvatski nogometni kup
# Already saved
#
# IRN2, Azadegan League
# Already saved
#
# GB4, League Two
# Already saved
#
# GB3, League One
# Already saved
#
# SER1, Super liga Srbije
# Already saved
#
# SER2, Prva liga Srbije
# Already saved
#
# SERP, Kup Srbije
# Already saved
#
# BESC, Belgian Supercup
# Already saved
#
# ES3B, 2ª B - Grupo II
# Already saved
#
# ES3A, 2ª B - Grupo I
# Already saved
#
# E3G1, Primera Federación - Gr. I
# Already saved
#
# E3FA, 2ª B - Fase de ascenso
# Already saved
#
# ES2, LaLiga2
# Already saved
#
# ES3P, Permanencia 2ª Federación
# Already saved
#
# RLSW, Regionalliga Südwest
# Already saved
#
# MEXA, Liga MX Apertura
# Already saved
#
# MEX1, Liga MX Clausura
# Already saved
#
# CPMX, Copa MX
# Already saved
#
# POMX, Liguilla Apertura
# Already saved
#
# POME, Liguilla Clausura
# Already saved
#
# NLBA, Beloften nacompetitie
# Already saved
#
# SUC, Supercopa
# Already saved
#
# BE2, Challenger Pro League
# Already saved
#
# QSJ1, Sheikh Jassim Cup
# Already saved
#
# POBE, JPL Playoff II
# Already saved
#
# BE2A, Proximus League Abst.
# Already saved
#
# ES2P, Promoción LaLiga2
# Already saved
#
# CNAT, National League
# Already saved
#
# FRCH, Trophée des Champions
# Already saved
#
# FRYC, Coupe Gambardella
# Already saved
#
# CN2D, National 2 - Grp. D
# Already saved
#
# TDV, Viareggio
# Already saved
#
# IJ1, Primavera 1
# Already saved
#
# E3PL, Promoción 2ª Federación
# Already saved
#
# ES1P, Promoción LaLiga
# Already saved
#
# ACLQ, AFC CL-Qualification
# Already saved
#
# TRS, TFF Süper Kupa
# Already saved
#
# WEPO, Intercontinental Cup
# Already saved
#
# ECSE, Serie A Segunda Etapa
# https://transfermarkt.com/serie-a-segunda-etapa-bis-2018-/startseite/wettbewerb/ECSE
# {'country': 'Ecuador',
#  'league_id': 'ECSE',
#  'league_name': 'Serie A Segunda Etapa',
#  'league_tier': 'First Tier',
#  'league_url': '/serie-a-segunda-etapa-bis-2018-/startseite/wettbewerb/ECSE',
#  'type': 'league'}
#
# ECPE, Serie A Primera Etapa
# https://transfermarkt.com/serie-a-primera-etapa-bis-2018-/startseite/wettbewerb/ECPE
# {'country': 'Ecuador',
#  'league_id': 'ECPE',
#  'league_name': 'Serie A Primera Etapa',
#  'league_tier': 'First Tier',
#  'league_url': '/serie-a-primera-etapa-bis-2018-/startseite/wettbewerb/ECPE',
#  'type': 'league'}
#
# MXCA, Copa MX Apertura
# Already saved
#
# USMX, Leagues Cup
# Already saved
#
# MXCC, Copa MX Clausura
# Already saved
#
# ECPL, Serie A Tercera Etapa
# https://transfermarkt.com/serie-a-tercera-etapa-bis-2018-/startseite/wettbewerb/ECPL
# {'country': 'Ecuador',
#  'league_id': 'ECPL',
#  'league_name': 'Serie A Tercera Etapa',
#  'league_tier': 'Play-Offs',
#  'league_url': '/serie-a-tercera-etapa-bis-2018-/startseite/wettbewerb/ECPL',
#  'type': 'league'}
#
# MXSC, Campeón de Campeones
# Already saved
#
# MEXB, Liga Expansión MX Ap.
# Already saved
#
# MEX2, Liga Expansión MX Cl.
# Already saved
#
# A1, Bundesliga
# Already saved
#
# ofb, ÖFB-Cup
# Already saved
#
# GHPL, Premier League
# Already saved
#
# A1EL, Bundesliga EL-Play-off
# Already saved
#
# NLBB, Beloften Eerste Divisie
# Already saved
#
# AUS1, A-League Men
# Already saved
#
# AUSF, A-League Fin.
# Already saved
#
# MLSR, MLS Reserve League
# Already saved
#
# BRA1, Série A
# Already saved
#
# RL3, RL West
# Already saved
#
# OL8, Oberliga Südwest
# Already saved
#
# AJ, U19-Bundesliga Endrunde
# Already saved
#
# NLAP, Play-Off U19 Eredivisie
# Already saved
#
# DK1, Superligaen
# Already saved
#
# DKP, Sydbank Pokalen
# Already saved
#
# DKMR, Superligaen Championship round
# Already saved
#
# DKRE, Future Cup
# Already saved
#
# DKRQ, Reserveligaen Spring
# Already saved
#
# POG3, League One Play-Offs
# Already saved
#
# GBQ1, U21 PL Qualificationsgr. 1
# Already saved
#
# GBKN, U21 PL Knockout
# Already saved
#
# CN2C, National 2 - Grp. C
# Already saved
#
# E3G2, Primera Federación - Gr. II
# Already saved
#
# E3FI, 2ª B - Fase intermedia
# Already saved
#
# AJ1, U19-BL N/NE
# Already saved
#
# EL1S, Serie A Segunda Etapa
# https://transfermarkt.com/ligapro-serie-a-segunda-etapa/startseite/wettbewerb/EL1S
# {'country': 'Ecuador',
#  'league_id': 'EL1S',
#  'league_name': 'Serie A Segunda Etapa',
#  'league_tier': 'First Tier',
#  'league_url': '/ligapro-serie-a-segunda-etapa/startseite/wettbewerb/EL1S',
#  'type': 'league'}
#
# EL1A, Serie A Primera Etapa
# https://transfermarkt.com/ligapro-serie-a-primera-etapa/startseite/wettbewerb/EL1A
# {'country': 'Ecuador',
#  'league_id': 'EL1A',
#  'league_name': 'Serie A Primera Etapa',
#  'league_tier': 'First Tier',
#  'league_url': '/ligapro-serie-a-primera-etapa/startseite/wettbewerb/EL1A',
#  'type': 'league'}
#
# ECUP, Copa Ecuador
# https://transfermarkt.com/copa-ecuador/startseite/pokalwettbewerb/ECUP
# {'country': 'Ecuador',
#  'league_id': 'ECUP',
#  'league_name': 'Copa Ecuador',
#  'league_tier': 'Domestic Cup',
#  'league_url': '/copa-ecuador/startseite/pokalwettbewerb/ECUP',
#  'type': 'cup'}
#
# LPPL, Serie A Tercera Etapa
# https://transfermarkt.com/ligapro-serie-a-tercera-etapa/startseite/pokalwettbewerb/LPPL
# {'country': 'Ecuador',
#  'league_id': 'LPPL',
#  'league_name': 'Serie A Tercera Etapa',
#  'league_tier': 'First Tier',
#  'league_url': '/ligapro-serie-a-tercera-etapa/startseite/pokalwettbewerb/LPPL',
#  'type': 'cup'}
#
# RECO, Recopa Sudamericana
# Already saved
#
# ECSC, Supercopa Ecuador
# https://transfermarkt.com/supercopa-ecuador/startseite/pokalwettbewerb/ECSC
# {'country': 'Ecuador',
#  'league_id': 'ECSC',
#  'league_name': 'Supercopa Ecuador',
#  'league_tier': 'Domestic Super Cup',
#  'league_url': '/supercopa-ecuador/startseite/pokalwettbewerb/ECSC',
#  'type': 'cup'}
#
# C1, Super League
# Already saved
#
# CHPR, Promotion League
# Already saved
#
# CH18, Swiss U18 Elite League
# Already saved
#
# SCC, Swiss Cup
# Already saved
#
# CHUC, Schweizer U18-Cup
# Already saved
#
# TUN1, Ligue I Pro
# Already saved
#
# TUNP, Tunisian Cup
# Already saved
#
# TUNM, Ligue I Pro Playoff
# Already saved
#
# CAFC, CAF Confederation Cup
# Already saved
#
# SAUP, Saudi Crown Prince's Cup
# Already saved
#
# SASS, Saudi Super Cup
# Already saved
#
# NTD, Jack’s League
# Already saved
#
# FFAC, FFA Cup
# Already saved
#
# ESJP, Jupiler Pro League playoff Europa League
# Already saved
#
# CITP, Coppa Primavera
# Already saved
#
# ITJE, Primavera Fase Finale
# Already saved
#
# ITJ2, Primavera B
# Already saved
#
# BJ, U17-Bundesliga Endrunde
# Already saved
#
# PL2, Fortuna 1 Liga
# Already saved
#
# ITJ3, Primavera C
# Already saved
#
# RSK2, K League 2
# Already saved
#
# RSK1, K League 1
# Already saved
#
# GR1, Super League 1
# Already saved
#
# RKPO, Korean FA Cup
# Already saved
#
# RUP, Russian Cup
# Already saved
#
# BU1, efbet Liga
# Already saved
#
# RO1, SuperLiga
# Already saved
#
# SR1C, Super liga Championship round
# Already saved
#
# ROMP, Cupa României
# Already saved
#
# BULP, Bulgarian Cup
# Already saved
#
# BU2, Vtora Liga
# Already saved
#
# BULS, Bulgarian Super Cup
# Already saved
#
# CR1, 1.Liga gr. 1
# Already saved
#
# POT3, Süper Final Europa
# Already saved
#
# PLSC, Superpuchar
# Already saved
#
# CN2A, National 2 - Grp. A
# Already saved
#
# 510, Derde Divisie Saturday
# Already saved
#
# NLAE, U19 Eerste Divisie
# Already saved
#
# IT2, Serie B
# Already saved
#
# POSB, Serie B Play-off
# Already saved
#
# CRPO, Copa de Costa Rica
# Already saved
#
# CVSP, Clausura Second Stage
# Already saved
#
# CVF, Clausura Finale
# Already saved
#
# RSKM, K League 1 Final A
# Already saved
#
# RSKA, K League 1 Final B
# Already saved
#
# KLCP, K League Cup
# Already saved
#
# KREG, K1 Promotion Playoff
# Already saved
#
# EBEL, Endrunde Jupiler Pro League
# Already saved
#
# ITJ1, Primavera A
# Already saved
#
# DK2, 1.Division
# Already saved
#
# C18E, Swiss U18 Elite Finals
# Already saved
#
# GBRS, Reserve League South
# Already saved
#
# DKAR, Superligaen Relegation round
# Already saved
#
# DKPL, Superligaen Playoffs
# Already saved
#
# URUE, Camp. Uruguayo Esp.
# Already saved
#
# MNP3, MLS Next Pro
# Already saved
#
# RL2, Regionalliga Süd
# Already saved
#
# JASP, Jap. Super Cup
# Already saved
#
# GRP, Kypello Elladas
# Already saved
#
# POGR, SL1 Play-off
# Already saved
#
# RUJL, U19 M-Liga
# Already saved
#
# SCIJ, Supercoppa Primavera
# Already saved
#
# DKDD, U19 Boys Division
# Already saved
#
# DKDL, U19 Boys League
# Already saved
#
# DK3V, 2.Division Promotion
# Already saved
#
# DK3O, 2.Division
# Already saved
#
# DKDA, 2.Division Relegation
# Already saved
#
# BCP1, Paulistão A1 - Primeira fase
# Already saved
#
# BRC, Copa do Brasil
# Already saved
#
# BCPF, Paulistão A1 - Fase final
# Already saved
#
# SLO1, Fortuna Liga
# Already saved
#
# SLMR, Fort. Liga - Releg. G.
# Already saved
#
# SLAR, Fort. Liga - Champ. G.
# Already saved
#
# SK2, II. Liga
# Already saved
#
# SKC, Slovnaft Cup
# Already saved
#
# SWEP, Fortuna L. - Conf. L. Playoff
# Already saved
#
# SK2P, II. Liga Promotion
# Already saved
#
# JAP2, J2 League
# Already saved
#
# JL11, J1 - 1st Stage
# Already saved
#
# JL12, J1 - 2nd Stage
# Already saved
#
# SUNC, J. League Championship
# Already saved
#
# SURU, YBC / Copa Sudamericana Supercup
# Already saved
#
# BRA2, Série B
# Already saved
#
# A2, 2. Liga
# Already saved
#
# CHC2, 1. Liga gr. 2
# Already saved
#
# C2, Challenge League
# Already saved
#
# SUIC, Swiss Cup qualifiers
# Already saved
#
# CHC1, 1. Liga gr. 1
# Already saved
#
# ROCL, Cupa Ligii
# Already saved
#
# CISP, Apertura Segunda Fase
# Already saved
#
# ARG2, Primera Nacional
# Already saved
#
# COL1, Liga DIMAYOR II
# Already saved
#
# COLP, Liga Dimayor I
# Already saved
#
# CDLP, Copa de la Liga
# Already saved
#
# COLF, Fase Final LBD I
# Already saved
#
# COLO, Fase Final LBD II
# Already saved
#
# COSP, Superliga Águila de Campeones
# Already saved
#
# CDCA, Copa de la Liga - Playoffs
# Already saved
#
# ARLC, Copa Superliga
# Already saved
#
# SCAG, Supercopa Argentina
# Already saved
#
# COPO, Copa Colombia
# Already saved
#
# TDCS, Trofeo de Campeones Superliga
# Already saved
#
# BU1A, Efbet liga - Relegation gr.
# Already saved
#
# PL31, 3 Liga - Group I
# Already saved
#
# RUSS, Russian Super Cup
# Already saved
#
# ES3D, 2ª B - Grupo IV
# Already saved
#
# K18C, K League U18 Championship
# Already saved
#
# CH17, Swiss U17 Elite League
# Already saved
#
# SE1, Allsvenskan
# Already saved
#
# NO1, Eliteserien
# Already saved
#
# NO2, OBOS-ligaen
# Already saved
#
# RTIP, Relegation Eliteserien
# Already saved
#
# NOPO, NM-Cup
# Already saved
#
# SEC, Svenska Cupen
# Already saved
#
# E21P, PL2 Playoffs
# Already saved
#
# EGY1, Premier League
# Already saved
#
# EGYP, Egypt Cup
# Already saved
#
# ESCU, Egyptian Super Cup
# Already saved
#
# RLN3, Regionalliga Nord
# Already saved
#
# NDSP, NDS-Pokal (bis 17/18)
# Already saved
#
# HEPO, Hessenpokal
# Already saved
#
# BJ1, U17-Bundesliga Nord/Nordost
# Already saved
#
# L2PO, Relegation 2. Bundesliga
# Already saved
#
# KREL, K League Championship
# Already saved
#
# GBRN, Reserve League North
# Already saved
#
# WER1, Vysheyshaya Liga
# Already saved
#
# WRPO, Belarusian Cup
# Already saved
#
# WERM, Wyschejschaja Liha Meisterrunde
# Already saved
#
# WRSP, Belarusian Super Cup
# Already saved
#
# CR2, 1.Liga gr. 2
# Already saved
#
# CCC1, Carib. Club Championship
# Already saved
#
# MXBA, Liguilla de Expansión Apertura
# Already saved
#
# CSL, Super League
# Already saved
#
# RKNL, Korea National League ('11-19')
# Already saved
#
# CSLC, CSL Championship Play-Offs
# Already saved
#
# KNPL, KNL Championship ('03-'19)
# Already saved
#
# CHFA, Chinese FA Cup
# Already saved
#
# USC3, USL1
# Already saved
#
# NCD1, NCAA D1 College Cup
# Already saved
#
# EJPD, Jupiler Pro League Abstiegs-Playoffs
# Already saved
#
# CSLR, CSL Relegation Play-Offs
# Already saved
#
# J1PO, J1 Play-off
# Already saved
#
# UKRA, Premier Liga - Abstiegsrunde
# Already saved
#
# UKR1, Premier Liga
# Already saved
#
# UARP, Rel. Premier Liga
# Already saved
#
# UKRP, Ukrainian Cup
# Already saved
#
# PT23, Liga Revelação
# Already saved
#
# BRga, Gaúcho - 2º Turno - Grupos
# Already saved
#
# CLIY, U20 Libertadores
# Already saved
#
# EC1N, LigaPro Serie A
# https://transfermarkt.com/ligapro-serie-a/startseite/wettbewerb/EC1N
# {'country': 'Ecuador',
#  'league_id': 'EC1N',
#  'league_name': 'LigaPro Serie A',
#  'league_tier': 'First Tier',
#  'league_url': '/ligapro-serie-a/startseite/wettbewerb/EC1N',
#  'type': 'league'}
#
# OLW3, Oberliga Westfalen
# Already saved
#
# NAFC, NASL Fall Championship
# Already saved
#
# NASC, NASL Spring Championship
# Already saved
#
# CDCO, Copa D. Maradona - Compl.
# Already saved
#
# SC2, Championship
# Already saved
#
# UNG1, NB I.
# Already saved
#
# RO1R, Liga 1 - Relegation group
# Already saved
#
# UNGP, Magyar Kupa
# Already saved
#
# P232, Liga Revelacao - Second Round
# Already saved
#
# P23C, Revelação U23 - Championship
# Already saved
#
# PTPR, U-23 Cup Portugal
# Already saved
#
# OBLG, NOFV-Oberliga Süd
# Already saved
#
# CIR5, 2. Liga Inter - Gr. 5
# Already saved
#
# CHC3, 1. Liga gr. 3
# Already saved
#
# SL1, Prva Liga
# Already saved
#
# SLP, Pokal Slovenije
# Already saved
#
# CHSC, Chinese Super Cup
# Already saved
#
# CR3, 1.Liga gr. 3
# Already saved
#
# RLN4, Regionalliga Northeast
# Already saved
#
# MEXP, InterLiga
# Already saved
#
# NO32, PostNord-ligaen Avd. 2
# Already saved
#
# UEQ, UEFA-Cup Qualifikation
# Already saved
#
# IT3B, Serie C - B
# Already saved
#
# IT3P, Playoff Serie C
# Already saved
#
# GBQ2, U21 PL Qualificationsgr. 2
# Already saved
#
# SCBR, Supercopa do Brasil
# Already saved
#
# DKRL, Superligaen Releg.
# Already saved
#
# RLB3, Regionalliga Bayern
# Already saved
#
# WFPO, Westfalenpokal
# Already saved
#
# AJR2, U19-Relegation Süd/Südwest
# Already saved
#
# QWEP, DFB-Pokal-Quali
# Already saved
#
# SC14, Supercopa MX
# Already saved
#
# OBLL, Oberliga Schleswig-Holstein
# Already saved
#
# S1PO, SL1 Play-out
# Already saved
#
# CIR3, 2. Liga Inter - Gr. 3
# Already saved
#
# PLJF, CYL - Final round
# Already saved
#
# PLJW, CYL - East
# Already saved
#
# TUSC, Tunesischer Supercup
# Already saved
#
# POT1, Süper Final Championship
# Already saved
#
# RS, Regionalliga Süd
# Already saved
#
# CIR4, 2. Liga Inter - Gr. 4
# Already saved
#
# BASU, Super League Barrage
# Already saved
#
# KAS1, Premier Liga
# Already saved
#
# KAZM, Premier League Championship-Playoff
# Already saved
#
# UALC, UAE League Cup
# Already saved
#
# SC4, League Two
# Already saved
#
# SSC, Challenge Cup
# Already saved
#
# SC1P, Premiership Play-offs
# Already saved
#
# SL, North American SuperLiga
# Already saved
#
# JGD2, ÖFB Jugendliga U18
# Already saved
#
# GBRP, Reserve League Play Offs
# Already saved
#
# RUSR, Relegation Premier Liga
# Already saved
#
# PLJZ, CYL - West
# Already saved
#
# PL32, 3 Liga - Group II
# Already saved
#
# PL2L, eWinner 2 liga
# Already saved
#
# ALPL, Liguilla Pre-Libertadores
# Already saved
#
# TS1, Fortuna Liga
# Already saved
#
# RN, Regionalliga Nord
# Already saved
#
# RL1, RL Nord (bis 11/12)
# Already saved
#
# UI, UI Cup
# Already saved
#
# S21N, U21 Allsvenskan Norra
# Already saved
#
# S21P, U21 Allsvenskan Slutspelet
# Already saved
#
# AFCC, AFC Cup
# Already saved
#
# REKR, Releg. 1.HNL
# Already saved
#
# IT4F, Serie D - F
# Already saved
#
# IT3C, Serie C - C
# Already saved
#
# IT3A, Serie C - A
# Already saved
#
# ITC4, Coppa Serie D
# Already saved
#
# CILP, Coppa Serie C
# Already saved
#
# SCIC, Supercoppa C
# Already saved
#
# IT4P, Play-off Serie D
# Already saved
#
# SE3S, Ettan Södra
# Already saved
#
# SE2, Superettan
# Already saved
#
# URU2, Liga de Ascenso
# Already saved
#
# URE2, Segunda División Profesional - Especial
# Already saved
#
# C3CM, N 3 - Corse-Méditer.
# Already saved
#
# C3BR, N 3 - Bretagne
# Already saved
#
# UKRS, Ukrainian Super Cup
# Already saved
#
# ITJ4, Under 17 - A
# Already saved
#
# AR3L, Aufstiegsrunde zur 3. Liga
# Already saved
#
# BRCM, Campeonato Mineiro
# Already saved
#
# POCO, National League Playoffs
# Already saved
#
# POAR, Relegation Play-off
# Already saved
#
# NLEV, Preliminary round U19 Eerste Divisie
# Already saved
#
# RRLB, Aufstiegsrunde RL Bayern
# Already saved
#
# UKRM, Premier Liga - Meisterrunde
# Already saved
#
# BRRS, Campeonato Gaúcho
# Already saved
#
# OL6, Oberliga Westfalen
# Already saved
#
# LPO, Ligapokal
# Already saved
#
# OLNI, Oberliga Niederrhein
# Already saved
#
# UASC, UAE Super Cup
# Already saved
#
# SAUR, SPL Relegation Playoffs
# Already saved
#
# POG2, League Two Play-Offs
# Already saved
#
# BRCG, Carioca - Taça Guanabara
# Already saved
#
# BRCF, Campeonato Carioca - Final
# Already saved
#
# BRCR, Carioca - Taça Rio
# Already saved
#
# CA1F, CanPL Fall Season
# Already saved
#
# CAN1, CanPL Spring Season
# Already saved
#
# CAPL, CanPL Playoffs
# Already saved
#
# C1P1, Liga DIMAYOR Liguilla
# Already saved
#
# URP1, Copa AUF Uruguay
# Already saved
#
# IJ2A, Primavera 2 - A
# Already saved
#
# BE2E, Final Proximus League
# Already saved
#
# OBLB, Oberliga Baden-Württemberg
# Already saved
#
# SLI, Sachsenliga
# Already saved
#
# WAL1, Cymru Premier
# Already saved
#
# WALE, Welsh Cup
# Already saved
#
# CLPD, Primera División
# https://transfermarkt.com/primera-division-de-chile/startseite/wettbewerb/CLPD
# {'country': 'Chile',
#  'league_id': 'CLPD',
#  'league_name': 'Primera División',
#  'league_tier': 'First Tier',
#  'league_url': '/primera-division-de-chile/startseite/wettbewerb/CLPD',
#  'type': 'league'}
#
# ITJ6, Under 17 - C
# Already saved
#
# ITJ7, Under 18 - A
# Already saved
#
# ITJF, Under 17 - finals
# Already saved
#
# TSP, MOL Cup
# Already saved
#
# T1MR, Fortuna Liga Champ. Gr.
# Already saved
#
# PLZJ, Youth League
# Already saved
#
# TUNR, Ligue Professionelle 1 - Relegation
# Already saved
#
# SWRP, Fortuna L. - Rel. Playoff
# Already saved
#
# T211, U21 Süper Lig
# Already saved
#
# TRP2, Süper Lig Reserves League
# Already saved
#
# ZYP1, Protathlima Cyta
# Already saved
#
# CPO1, Kypello Kyprou
# Already saved
#
# MXBC, Liguilla de Expansión Clausura
# Already saved
#
# CDN1, CanPL
# Already saved
#
# NZL1, NZ Premiership (- 2021)
# Already saved
#
# CIR1, 2. Liga Inter - Gr. 1
# Already saved
#
# ISR1, Ligat ha'Al
# Already saved
#
# ISRF, Ligat ha'Al -  Championship round
# Already saved
#
# ISPO, Gavia haMedina
# Already saved
#
# TUPL, Ligue I Pro Playout
# Already saved
#
# GRS2, Super League 2
# Already saved
#
# PL33, 3 Liga - Group III
# Already saved
#
# PLJR, Baraże o udział w CLJ
# Already saved
