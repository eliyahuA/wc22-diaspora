# %%
'''
This scripts collects information about
each player. It collects his basic information,
his transfer history and all the leagues he played for.
'''
# Out:
# '\nThis scripts collects information about\neach player. It collects his basic information,\nhis transfer history and all the leagues he played for.\n'

# %%
from bs4 import BeautifulSoup
from io import BytesIO
import glob
import json
import pandas as pd
from pathlib import Path
from pprint import pprint
import requests
import re
from tqdm.notebook import tqdm
import time

# %%
HEADERS = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'
    }

# %%
def already_saved(player_id):
    '''
    Controls whether the data for this specific player
    was already saved properly. Returns true or false.
    
    Params:
    
    player_id -> string with the unique player id at Transfermarkt
    '''
    
    player_files = glob.glob("../output/players/basic-info-*.json")
    transfer_files = glob.glob("../output/players/transfer-info-*.json")
    league_files = glob.glob("../output/players/league-info-*.json")
    club_files = glob.glob("../output/players/club-info-*.json")
    
    player_files = list(map(lambda x: re.search("\d+", x).group(0), player_files))
    transfer_files = list(map(lambda x: re.search("\d+", x).group(0), transfer_files))
    league_files = list(map(lambda x: re.search("\d+", x).group(0), league_files))
    club_files = list(map(lambda x: re.search("\d+", x).group(0), club_files))
    
    if player_id in player_files and player_id in league_files and \
    player_id in club_files and player_id in transfer_files:
        
        return True

# %%
def player_page_request(player_url): 
    '''
    Makes a request to the page containing
    detailed information about the player
    and returns it as a response object.
    
    Params:
    
    player_url -> string with the url path to the player page at Transfermarkt
    '''
    
    r = requests.get(player_url, headers=HEADERS)
    
    return r

# %%
def scrape_basic_info(player_r):
    '''
    Collects the basic player information.
    
    Params:
    
    player_r -> a response object retrieved from 
    the player page at transfermarkt
    '''
    
    player_info = {}
    
    soup = BeautifulSoup(player_r.text)

    player_data = soup.find('div', class_='info-table')
    categories = player_data.find_all('span', class_='info-table__content--regular')
    values = player_data.find_all('span', class_='info-table__content--bold')

    for cat, val in zip(categories, values):
        
        if cat.text.strip() in ['Name in home country:', 'Full name:', 'Date of birth:', 
                        'Age:', 'Height:', 
                        'Position:', 'Foot:', 'Current club:', 'Joined:']:

            label = cat.text.replace(":", "").strip().lower().replace(" ", "_")
            item = val.text.strip()

            player_info[label] = item
            
        if cat.text.strip() in ['Current club:']:
            player_info['current_club_url'] = val.find('a', href=True)['href']
            player_info['current_club_id'] = re.search("/verein/(\d+)", player_info['current_club_url']).group(1)


        if cat.text.strip() == "Citizenship:":
            citizenship = val.find("img", class_="flaggenrahmen", alt=True)['alt'] # In cases of double citizenship, this will get the first one only
            player_info['citizenship'] = citizenship
            
        if cat.text.strip() == 'Place of birth:':

            # Add country before saving
            label = cat.text.replace(":", "").strip().lower().replace(" ", "_")

            country = val.find('img', class_='flaggenrahmen', alt=True)['alt']
            item = f'{val.text.strip()}, {country}'

            player_info[label] = item
            
    return player_info

# %%
def save_json(data, outpath):
    '''
    Saves a JSON file in the specified output path
    '''
    with open(outpath, 'w+') as f:
        json.dump(data, f)

# %%
def scrape_transfer_info(player_r):
    '''
    Scrapes all transfers from a player
    
    Params:
    
    player_r -> a response object retrieved from 
    the player page at transfermarkt
    '''
    
    soup = BeautifulSoup(player_r.text)
    transfers = soup.find_all('div', class_='grid tm-player-transfer-history-grid')
    
    rows = []

    for transfer in transfers:
        entries = transfer.find_all("div", class_="grid__cell")
        # Removes the fee and market value entries
        entries = entries[:-2]

        season = entries[0].text.strip()
        date = entries[1].text.strip()
        left = entries[2].text.strip()
        left_url = entries[2].find('a')['href']
        left_club_id = re.search('verein/(\d+)/saison_id/', left_url).group(1)
        joined = entries[3].text.strip()
        joined_url = entries[3].find('a')['href']
        joined_club_id = re.search('verein/(\d+)/saison_id/', joined_url).group(1)

        datum = {
            'season': season,
            'date': date,
            'left': left,
            'left_url': left_url,
            'left_club_id': left_club_id,
            'joined': joined,
            'joined_url': joined_url,
            'joined_club_id': joined_club_id,

        }

        rows.append(datum)
        
    return rows

# %%
def scrape_league_info(player_id):
    '''
    Scrapes the league information for each player.

    Params:

    player_id -> string with the unique player id at Transfermarkt
    '''
    
    # Funny, we don't actually need the player name on the url
    league_details_url = f'https://www.transfermarkt.com/dummy/leistungsdaten/spieler/{player_id}/plus/0?saison=ges'
    print(league_details_url)
    
    time.sleep(1)

    r = requests.get(league_details_url, headers=HEADERS)
    soup = BeautifulSoup(r.text)
    
    
    league_table_div = soup.find('div', class_='responsive-table')
    league_table = league_table_div.find("table", class_='items')
    tbody = league_table.find("tbody")
    
    rows = tbody.find_all("tr")
    
    data = []
    for row in rows:
        cells = row.find_all("td")

        league = cells[1].find('a')
        league_url = league['href']
        league_name = league['title']
        league_id = re.search("\/startseite\/\w+\/(.+)", league_url).group(1)

        matches = cells[2].text
        minutes = cells[-1].text

        datum = {
            "league_url": league_url,
            "league_name": league_name,
            "league_id": league_id,
            "matches": matches,
            "minutes": minutes,
        }
        
        data.append(datum)
                  

    return data

# %%
def scrape_club_info(player_id):
    '''
    Scrapes the club information for each player.
    
    Params:

    player_id -> string with the unique player id at Transfermarkt
    '''
    
    club_details_url = f'https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/{player_id}'
    print(club_details_url)
    
    time.sleep(1)

    
    r = requests.get(club_details_url, headers=HEADERS)
    soup = BeautifulSoup(r.text)

    club_table_div = soup.find('div', class_='responsive-table')
    club_table = club_table_div.find("table", class_='items')
    
    tbody = club_table.find("tbody")
    
    rows = tbody.find_all("tr")
    
    data = []
    for row in rows:
        cells = row.find_all("td")

        club = cells[1].find('a')
        club_url = club['href']
        club_name = club['title']
        club_id = re.search("\/startseite\/\w+\/(.+)", club_url).group(1)

        matches = cells[2].text
        minutes = cells[-1].text

        datum = {
            "club_url": club_url,
            "club_name": club_name,
            "club_id": club_id,
            "matches": matches,
            "minutes": minutes,
        }
        
        data.append(datum)
                  

    return data

# %%
def main():
    
    df = pd.read_csv('../output/2022-wikipedia-to-transfermarkt.csv', sep=',')
    
    all_files = glob.glob("../output/players/*.json")
    right_ids = df.transfermarkt_id.astype(str).unique().tolist()
        
    for file in all_files:
        
        id_ = re.search("(\d+)", file).group(1)
        
        if id_ not in right_ids:
            print('deleting', file) # to do – turn into delete
            file_to_rem = Path(file)
            file_to_rem.unlink()
    
    for index, row in tqdm(df.iterrows(), total=df.shape[0]):
                
        print(row.wikipedia_page)
        
        # Progress check
        player_url = f"https://www.transfermarkt.com/dummy/profil/spieler/{row.transfermarkt_id}"
        player_id = re.search('/spieler/(\d+)', player_url).group(1)

        if already_saved(player_id):
            print("Already collected!")
            print()
            continue
            

        # If the players was not saved, let's fetch basic data
        print(player_url)
        player_r = player_page_request(player_url)
        
        time.sleep(1)

        player_info = scrape_basic_info(player_r)
#         player_info['fetched_name'] = row.fetched_name
#         player_info['national_team'] = row.team
        save_json(player_info, f"../output/players/basic-info-{player_id}.json")
        
        # Scrapes transfer data
        transfer_info = scrape_transfer_info(player_r)
        save_json(transfer_info, f"../output/players/transfer-info-{player_id}.json")

        # Collect league data
        league_info = scrape_league_info(player_id)
        save_json(league_info, f"../output/players/league-info-{player_id}.json")

          # Collect club data
        club_info = scrape_club_info(player_id)
        save_json(club_info, f"../output/players/club-info-{player_id}.json")

        print()

# %%
if __name__ == "__main__":
    main()
# Out:
#   0%|          | 0/831 [00:00<?, ?it/s]
# https://en.wikipedia.org/wiki/Remko_Pasveer
# Already collected!
#
# https://en.wikipedia.org/wiki/Jurri%C3%ABn_Timber
# Already collected!
#
# https://en.wikipedia.org/wiki/Matthijs_de_Ligt
# Already collected!
#
# https://en.wikipedia.org/wiki/Virgil_van_Dijk
# Already collected!
#
# https://en.wikipedia.org/wiki/Nathan_Ak%C3%A9
# Already collected!
#
# https://en.wikipedia.org/wiki/Stefan_de_Vrij
# Already collected!
#
# https://en.wikipedia.org/wiki/Steven_Bergwijn
# Already collected!
#
# https://en.wikipedia.org/wiki/Cody_Gakpo
# Already collected!
#
# https://en.wikipedia.org/wiki/Luuk_de_Jong
# Already collected!
#
# https://en.wikipedia.org/wiki/Memphis_Depay
# Already collected!
#
# https://en.wikipedia.org/wiki/Steven_Berghuis
# Already collected!
#
# https://en.wikipedia.org/wiki/Noa_Lang
# Already collected!
#
# https://en.wikipedia.org/wiki/Justin_Bijlow
# Already collected!
#
# https://en.wikipedia.org/wiki/Davy_Klaassen
# Already collected!
#
# https://en.wikipedia.org/wiki/Marten_de_Roon
# Already collected!
#
# https://en.wikipedia.org/wiki/Tyrell_Malacia
# Already collected!
#
# https://en.wikipedia.org/wiki/Daley_Blind
# Already collected!
#
# https://en.wikipedia.org/wiki/Vincent_Janssen
# Already collected!
#
# https://en.wikipedia.org/wiki/Wout_Weghorst
# Already collected!
#
# https://en.wikipedia.org/wiki/Teun_Koopmeiners
# Already collected!
#
# https://en.wikipedia.org/wiki/Frenkie_de_Jong
# Already collected!
#
# https://en.wikipedia.org/wiki/Denzel_Dumfries
# Already collected!
#
# https://en.wikipedia.org/wiki/Andries_Noppert
# Already collected!
#
# https://en.wikipedia.org/wiki/Kenneth_Taylor_(footballer,_born_2002)
# Already collected!
#
# https://en.wikipedia.org/wiki/Xavi_Simons
# Already collected!
#
# https://en.wikipedia.org/wiki/Jeremie_Frimpong
# Already collected!
#
# https://en.wikipedia.org/wiki/Saad_Al-Sheeb
# Already collected!
#
# https://en.wikipedia.org/wiki/Meshaal_Barsham
# Already collected!
#
# https://en.wikipedia.org/wiki/Yousef_Hassan
# Already collected!
#
# https://en.wikipedia.org/wiki/Abdelkarim_Hassan
# Already collected!
#
# https://en.wikipedia.org/wiki/Boualem_Khoukhi
# Already collected!
#
# https://en.wikipedia.org/wiki/R%C3%B3-R%C3%B3
# Already collected!
#
# https://en.wikipedia.org/wiki/Ismaeel_Mohammad
# Already collected!
#
# https://en.wikipedia.org/wiki/Bassam_Al-Rawi
# Already collected!
#
# https://en.wikipedia.org/wiki/Tarek_Salman
# Already collected!
#
# https://en.wikipedia.org/wiki/Musab_Kheder
# Already collected!
#
# https://en.wikipedia.org/wiki/Homam_Ahmed
# Already collected!
#
# https://en.wikipedia.org/wiki/Jassem_Gaber
# Already collected!
#
# https://en.wikipedia.org/wiki/Karim_Boudiaf
# Already collected!
#
# https://en.wikipedia.org/wiki/Abdulaziz_Hatem
# Already collected!
#
# https://en.wikipedia.org/wiki/Ali_Assadalla
# Already collected!
#
# https://en.wikipedia.org/wiki/Assim_Madibo
# Already collected!
#
# https://en.wikipedia.org/wiki/Salem_Al-Hajri
# Already collected!
#
# https://en.wikipedia.org/wiki/Mohammed_Waad
# Already collected!
#
# https://en.wikipedia.org/wiki/Mostafa_Meshaal_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Hassan_Al-Haydos
# Already collected!
#
# https://en.wikipedia.org/wiki/Akram_Afif
# Already collected!
#
# https://en.wikipedia.org/wiki/Almoez_Ali
# Already collected!
#
# https://en.wikipedia.org/wiki/Mohammed_Muntari
# Already collected!
#
# https://en.wikipedia.org/wiki/Ahmed_Alaaeldin
# Already collected!
#
# https://en.wikipedia.org/wiki/Khalid_Muneer
# Already collected!
#
# https://en.wikipedia.org/wiki/Naif_Al-Hadhrami
# Already collected!
#
# https://en.wikipedia.org/wiki/%C3%89douard_Mendy
# Already collected!
#
# https://en.wikipedia.org/wiki/Alfred_Gomis
# Already collected!
#
# https://en.wikipedia.org/wiki/Seny_Dieng
# Already collected!
#
# https://en.wikipedia.org/wiki/Kalidou_Koulibaly
# Already collected!
#
# https://en.wikipedia.org/wiki/Youssouf_Sabaly
# Already collected!
#
# https://en.wikipedia.org/wiki/Abdou_Diallo
# Already collected!
#
# https://en.wikipedia.org/wiki/Fod%C3%A9_Ballo-Tour%C3%A9
# Already collected!
#
# https://en.wikipedia.org/wiki/Pape_Abou_Ciss%C3%A9
# Already collected!
#
# https://en.wikipedia.org/wiki/Ismail_Jakobs
# Already collected!
#
# https://en.wikipedia.org/wiki/Formose_Mendy_(footballer,_born_2001)
# Already collected!
#
# https://en.wikipedia.org/wiki/Idrissa_Gueye
# Already collected!
#
# https://en.wikipedia.org/wiki/Cheikhou_Kouyat%C3%A9
# Already collected!
#
# https://en.wikipedia.org/wiki/Kr%C3%A9pin_Diatta
# Already collected!
#
# https://en.wikipedia.org/wiki/Nampalys_Mendy
# Already collected!
#
# https://en.wikipedia.org/wiki/Pape_Gueye
# Already collected!
#
# https://en.wikipedia.org/wiki/Pape_Matar_Sarr
# Already collected!
#
# https://en.wikipedia.org/wiki/Moustapha_Name
# Already collected!
#
# https://en.wikipedia.org/wiki/Mamadou_Loum
# Already collected!
#
# https://en.wikipedia.org/wiki/Path%C3%A9_Ciss
# Already collected!
#
# https://en.wikipedia.org/wiki/Sadio_Man%C3%A9
# Already collected!
#
# https://en.wikipedia.org/wiki/Isma%C3%AFla_Sarr
# Already collected!
#
# https://en.wikipedia.org/wiki/Famara_Di%C3%A9dhiou
# Already collected!
#
# https://en.wikipedia.org/wiki/Boulaye_Dia
# Already collected!
#
# https://en.wikipedia.org/wiki/Bamba_Dieng
# Already collected!
#
# https://en.wikipedia.org/wiki/Iliman_Ndiaye
# Already collected!
#
# https://en.wikipedia.org/wiki/Nicolas_Jackson
# Already collected!
#
# https://en.wikipedia.org/wiki/Jordan_Pickford
# Already collected!
#
# https://en.wikipedia.org/wiki/Kyle_Walker
# Already collected!
#
# https://en.wikipedia.org/wiki/Luke_Shaw
# Already collected!
#
# https://en.wikipedia.org/wiki/Declan_Rice
# Already collected!
#
# https://en.wikipedia.org/wiki/John_Stones
# Already collected!
#
# https://en.wikipedia.org/wiki/Harry_Maguire
# Already collected!
#
# https://en.wikipedia.org/wiki/Jack_Grealish
# Already collected!
#
# https://en.wikipedia.org/wiki/Jordan_Henderson
# Already collected!
#
# https://en.wikipedia.org/wiki/Harry_Kane
# Already collected!
#
# https://en.wikipedia.org/wiki/Raheem_Sterling
# Already collected!
#
# https://en.wikipedia.org/wiki/Marcus_Rashford
# Already collected!
#
# https://en.wikipedia.org/wiki/Kieran_Trippier
# Already collected!
#
# https://en.wikipedia.org/wiki/Nick_Pope_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Kalvin_Phillips
# Already collected!
#
# https://en.wikipedia.org/wiki/Eric_Dier
# Already collected!
#
# https://en.wikipedia.org/wiki/Conor_Coady
# Already collected!
#
# https://en.wikipedia.org/wiki/Bukayo_Saka
# Already collected!
#
# https://en.wikipedia.org/wiki/Trent_Alexander-Arnold
# Already collected!
#
# https://en.wikipedia.org/wiki/Mason_Mount
# Already collected!
#
# https://en.wikipedia.org/wiki/Phil_Foden
# Already collected!
#
# https://en.wikipedia.org/wiki/Ben_White_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Jude_Bellingham
# Already collected!
#
# https://en.wikipedia.org/wiki/Aaron_Ramsdale
# Already collected!
#
# https://en.wikipedia.org/wiki/Callum_Wilson_(footballer,_born_1992)
# Already collected!
#
# https://en.wikipedia.org/wiki/James_Maddison
# Already collected!
#
# https://en.wikipedia.org/wiki/Conor_Gallagher
# Already collected!
#
# https://en.wikipedia.org/wiki/Alireza_Beiranvand
# Already collected!
#
# https://en.wikipedia.org/wiki/Amir_Abedzadeh
# Already collected!
#
# https://en.wikipedia.org/wiki/Hossein_Hosseini_(footballer,_born_1992)
# Already collected!
#
# https://en.wikipedia.org/wiki/Payam_Niazmand
# Already collected!
#
# https://en.wikipedia.org/wiki/Ehsan_Hajsafi
# Already collected!
#
# https://en.wikipedia.org/wiki/Morteza_Pouraliganji
# Already collected!
#
# https://en.wikipedia.org/wiki/Ramin_Rezaeian
# Already collected!
#
# https://en.wikipedia.org/wiki/Milad_Mohammadi
# Already collected!
#
# https://en.wikipedia.org/wiki/Hossein_Kanaanizadegan
# Already collected!
#
# https://en.wikipedia.org/wiki/Shojae_Khalilzadeh
# Already collected!
#
# https://en.wikipedia.org/wiki/Sadegh_Moharrami
# Already collected!
#
# https://en.wikipedia.org/wiki/Rouzbeh_Cheshmi
# Already collected!
#
# https://en.wikipedia.org/wiki/Majid_Hosseini
# Already collected!
#
# https://en.wikipedia.org/wiki/Abolfazl_Jalali
# Already collected!
#
# https://en.wikipedia.org/wiki/Vahid_Amiri
# Already collected!
#
# https://en.wikipedia.org/wiki/Alireza_Jahanbakhsh
# Already collected!
#
# https://en.wikipedia.org/wiki/Saeid_Ezatolahi
# Already collected!
#
# https://en.wikipedia.org/wiki/Mehdi_Torabi
# Already collected!
#
# https://en.wikipedia.org/wiki/Saman_Ghoddos
# Already collected!
#
# https://en.wikipedia.org/wiki/Ali_Gholizadeh
# Already collected!
#
# https://en.wikipedia.org/wiki/Ahmad_Nourollahi
# Already collected!
#
# https://en.wikipedia.org/wiki/Ali_Karimi_(footballer,_born_1994)
# Already collected!
#
# https://en.wikipedia.org/wiki/Karim_Ansarifard
# Already collected!
#
# https://en.wikipedia.org/wiki/Sardar_Azmoun
# Already collected!
#
# https://en.wikipedia.org/wiki/Mehdi_Taremi
# Already collected!
#
# https://en.wikipedia.org/wiki/Matt_Turner_(soccer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Sergi%C3%B1o_Dest
# Already collected!
#
# https://en.wikipedia.org/wiki/Walker_Zimmerman
# Already collected!
#
# https://en.wikipedia.org/wiki/Tyler_Adams
# Already collected!
#
# https://en.wikipedia.org/wiki/Antonee_Robinson
# Already collected!
#
# https://en.wikipedia.org/wiki/Yunus_Musah
# Already collected!
#
# https://en.wikipedia.org/wiki/Giovanni_Reyna
# Already collected!
#
# https://en.wikipedia.org/wiki/Weston_McKennie
# Already collected!
#
# https://en.wikipedia.org/wiki/Jes%C3%BAs_Ferreira
# Already collected!
#
# https://en.wikipedia.org/wiki/Christian_Pulisic
# Already collected!
#
# https://en.wikipedia.org/wiki/Brenden_Aaronson
# Already collected!
#
# https://en.wikipedia.org/wiki/Ethan_Horvath
# Already collected!
#
# https://en.wikipedia.org/wiki/Tim_Ream
# Already collected!
#
# https://en.wikipedia.org/wiki/Luca_de_la_Torre
# Already collected!
#
# https://en.wikipedia.org/wiki/Aaron_Long_(soccer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Jordan_Morris
# Already collected!
#
# https://en.wikipedia.org/wiki/Cristian_Roldan
# Already collected!
#
# https://en.wikipedia.org/wiki/Shaq_Moore
# Already collected!
#
# https://en.wikipedia.org/wiki/Haji_Wright
# Already collected!
#
# https://en.wikipedia.org/wiki/Cameron_Carter-Vickers
# Already collected!
#
# https://en.wikipedia.org/wiki/Timothy_Weah
# Already collected!
#
# https://en.wikipedia.org/wiki/DeAndre_Yedlin
# Already collected!
#
# https://en.wikipedia.org/wiki/Kellyn_Acosta
# Already collected!
#
# https://en.wikipedia.org/wiki/Josh_Sargent
# Already collected!
#
# https://en.wikipedia.org/wiki/Sean_Johnson_(soccer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Joe_Scally
# Already collected!
#
# https://en.wikipedia.org/wiki/Wayne_Hennessey
# Already collected!
#
# https://en.wikipedia.org/wiki/Danny_Ward_(Welsh_footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Adam_Davies_(footballer,_born_1992)
# Already collected!
#
# https://en.wikipedia.org/wiki/Chris_Gunter
# Already collected!
#
# https://en.wikipedia.org/wiki/Ben_Davies_(footballer,_born_1993)
# Already collected!
#
# https://en.wikipedia.org/wiki/Connor_Roberts_(footballer,_born_1995)
# Already collected!
#
# https://en.wikipedia.org/wiki/Ethan_Ampadu
# Already collected!
#
# https://en.wikipedia.org/wiki/Chris_Mepham
# Already collected!
#
# https://en.wikipedia.org/wiki/Joe_Rodon
# Already collected!
#
# https://en.wikipedia.org/wiki/Neco_Williams
# Already collected!
#
# https://en.wikipedia.org/wiki/Tom_Lockyer
# Already collected!
#
# https://en.wikipedia.org/wiki/Ben_Cabango
# Already collected!
#
# https://en.wikipedia.org/wiki/Aaron_Ramsey
# Already collected!
#
# https://en.wikipedia.org/wiki/Joe_Allen
# Already collected!
#
# https://en.wikipedia.org/wiki/Harry_Wilson_(footballer,_born_1997)
# Already collected!
#
# https://en.wikipedia.org/wiki/Jonny_Williams
# Already collected!
#
# https://en.wikipedia.org/wiki/Joe_Morrell
# Already collected!
#
# https://en.wikipedia.org/wiki/Matthew_Smith_(footballer,_born_1999)
# Already collected!
#
# https://en.wikipedia.org/wiki/Dylan_Levitt
# Already collected!
#
# https://en.wikipedia.org/wiki/Rubin_Colwill
# Already collected!
#
# https://en.wikipedia.org/wiki/Sorba_Thomas
# Already collected!
#
# https://en.wikipedia.org/wiki/Gareth_Bale
# Already collected!
#
# https://en.wikipedia.org/wiki/Daniel_James_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Kieffer_Moore
# Already collected!
#
# https://en.wikipedia.org/wiki/Brennan_Johnson
# Already collected!
#
# https://en.wikipedia.org/wiki/Mark_Harris_(Welsh_footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Emiliano_Mart%C3%ADnez
# Already collected!
#
# https://en.wikipedia.org/wiki/Franco_Armani
# Already collected!
#
# https://en.wikipedia.org/wiki/Ger%C3%B3nimo_Rulli
# Already collected!
#
# https://en.wikipedia.org/wiki/Nicol%C3%A1s_Otamendi
# Already collected!
#
# https://en.wikipedia.org/wiki/Marcos_Acu%C3%B1a
# Already collected!
#
# https://en.wikipedia.org/wiki/Nicol%C3%A1s_Tagliafico
# Already collected!
#
# https://en.wikipedia.org/wiki/Germ%C3%A1n_Pezzella
# Already collected!
#
# https://en.wikipedia.org/wiki/Nahuel_Molina
# Already collected!
#
# https://en.wikipedia.org/wiki/Gonzalo_Montiel
# Already collected!
#
# https://en.wikipedia.org/wiki/Juan_Foyth
# Already collected!
#
# https://en.wikipedia.org/wiki/Cristian_Romero_(footballer,_born_1998)
# Already collected!
#
# https://en.wikipedia.org/wiki/Lisandro_Mart%C3%ADnez
# Already collected!
#
# https://en.wikipedia.org/wiki/Leandro_Paredes
# Already collected!
#
# https://en.wikipedia.org/wiki/Rodrigo_De_Paul
# Already collected!
#
# https://en.wikipedia.org/wiki/Guido_Rodr%C3%ADguez
# Already collected!
#
# https://en.wikipedia.org/wiki/Exequiel_Palacios
# Already collected!
#
# https://en.wikipedia.org/wiki/Papu_G%C3%B3mez
# Already collected!
#
# https://en.wikipedia.org/wiki/Alexis_Mac_Allister
# Already collected!
#
# https://en.wikipedia.org/wiki/Enzo_Fern%C3%A1ndez_(footballer,_born_2001)
# Already collected!
#
# https://en.wikipedia.org/wiki/Lionel_Messi
# Already collected!
#
# https://en.wikipedia.org/wiki/%C3%81ngel_Di_Mar%C3%ADa
# Already collected!
#
# https://en.wikipedia.org/wiki/Lautaro_Mart%C3%ADnez
# Already collected!
#
# https://en.wikipedia.org/wiki/Paulo_Dybala
# Already collected!
#
# https://en.wikipedia.org/wiki/Nicol%C3%A1s_Gonz%C3%A1lez_(footballer,_born_1998)
# Already collected!
#
# https://en.wikipedia.org/wiki/Joaqu%C3%ADn_Correa
# Already collected!
#
# https://en.wikipedia.org/wiki/Juli%C3%A1n_%C3%81lvarez_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Guillermo_Ochoa
# Already collected!
#
# https://en.wikipedia.org/wiki/Alfredo_Talavera
# Already collected!
#
# https://en.wikipedia.org/wiki/Rodolfo_Cota
# Already collected!
#
# https://en.wikipedia.org/wiki/H%C3%A9ctor_Moreno
# Already collected!
#
# https://en.wikipedia.org/wiki/Jes%C3%BAs_Gallardo
# Already collected!
#
# https://en.wikipedia.org/wiki/N%C3%A9stor_Araujo
# Already collected!
#
# https://en.wikipedia.org/wiki/C%C3%A9sar_Montes
# Already collected!
#
# https://en.wikipedia.org/wiki/Jorge_S%C3%A1nchez_(footballer,_born_1997)
# Already collected!
#
# https://en.wikipedia.org/wiki/Gerardo_Arteaga
# Already collected!
#
# https://en.wikipedia.org/wiki/Kevin_%C3%81lvarez_(footballer,_born_1999)
# Already collected!
#
# https://en.wikipedia.org/wiki/Johan_V%C3%A1squez_(footballer,_born_1998)
# Already collected!
#
# https://en.wikipedia.org/wiki/Andr%C3%A9s_Guardado
# Already collected!
#
# https://en.wikipedia.org/wiki/H%C3%A9ctor_Herrera
# Already collected!
#
# https://en.wikipedia.org/wiki/Edson_%C3%81lvarez
# Already collected!
#
# https://en.wikipedia.org/wiki/Orbel%C3%ADn_Pineda
# Already collected!
#
# https://en.wikipedia.org/wiki/Uriel_Antuna
# Already collected!
#
# https://en.wikipedia.org/wiki/%C3%89rick_Guti%C3%A9rrez
# Already collected!
#
# https://en.wikipedia.org/wiki/Carlos_Alberto_Rodr%C3%ADguez
# Already collected!
#
# https://en.wikipedia.org/wiki/Roberto_Alvarado
# Already collected!
#
# https://en.wikipedia.org/wiki/Luis_Romo
# Already collected!
#
# https://en.wikipedia.org/wiki/Alexis_Vega_(footballer,_born_1997)
# Already collected!
#
# https://en.wikipedia.org/wiki/Luis_Ch%C3%A1vez_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Ra%C3%BAl_Jim%C3%A9nez
# Already collected!
#
# https://en.wikipedia.org/wiki/Hirving_Lozano
# Already collected!
#
# https://en.wikipedia.org/wiki/Henry_Mart%C3%ADn
# Already collected!
#
# https://en.wikipedia.org/wiki/Rogelio_Funes_Mori
# Already collected!
#
# https://en.wikipedia.org/wiki/Wojciech_Szcz%C4%99sny
# Already collected!
#
# https://en.wikipedia.org/wiki/%C5%81ukasz_Skorupski
# Already collected!
#
# https://en.wikipedia.org/wiki/Kamil_Grabara
# Already collected!
#
# https://en.wikipedia.org/wiki/Kamil_Glik
# Already collected!
#
# https://en.wikipedia.org/wiki/Bartosz_Bereszy%C5%84ski
# Already collected!
#
# https://en.wikipedia.org/wiki/Jan_Bednarek
# Already collected!
#
# https://en.wikipedia.org/wiki/Artur_J%C4%99drzejczyk
# Already collected!
#
# https://en.wikipedia.org/wiki/Matty_Cash
# Already collected!
#
# https://en.wikipedia.org/wiki/Nicola_Zalewski
# Already collected!
#
# https://en.wikipedia.org/wiki/Jakub_Kiwior
# Already collected!
#
# https://en.wikipedia.org/wiki/Robert_Gumny
# Already collected!
#
# https://en.wikipedia.org/wiki/Mateusz_Wieteska
# Already collected!
#
# https://en.wikipedia.org/wiki/Grzegorz_Krychowiak
# Already collected!
#
# https://en.wikipedia.org/wiki/Kamil_Grosicki
# Already collected!
#
# https://en.wikipedia.org/wiki/Piotr_Zieli%C5%84ski
# Already collected!
#
# https://en.wikipedia.org/wiki/Przemys%C5%82aw_Frankowski
# Already collected!
#
# https://en.wikipedia.org/wiki/Sebastian_Szyma%C5%84ski
# Already collected!
#
# https://en.wikipedia.org/wiki/Damian_Szyma%C5%84ski
# Already collected!
#
# https://en.wikipedia.org/wiki/Szymon_%C5%BBurkowski
# Already collected!
#
# https://en.wikipedia.org/wiki/Krystian_Bielik
# Already collected!
#
# https://en.wikipedia.org/wiki/Jakub_Kami%C5%84ski
# Already collected!
#
# https://en.wikipedia.org/wiki/Micha%C5%82_Sk%C3%B3ra%C5%9B
# Already collected!
#
# https://en.wikipedia.org/wiki/Robert_Lewandowski
# Already collected!
#
# https://en.wikipedia.org/wiki/Arkadiusz_Milik
# Already collected!
#
# https://en.wikipedia.org/wiki/Krzysztof_Pi%C4%85tek
# Already collected!
#
# https://en.wikipedia.org/wiki/Karol_%C5%9Awiderski
# Already collected!
#
# https://en.wikipedia.org/wiki/Mohammed_Al-Owais
# Already collected!
#
# https://en.wikipedia.org/wiki/Mohammed_Al-Rubaie
# Already collected!
#
# https://en.wikipedia.org/wiki/Nawaf_Al-Aqidi
# Already collected!
#
# https://en.wikipedia.org/wiki/Yasser_Al-Shahrani
# Already collected!
#
# https://en.wikipedia.org/wiki/Mohammed_Al-Breik
# Already collected!
#
# https://en.wikipedia.org/wiki/Ali_Al-Bulaihi
# Already collected!
#
# https://en.wikipedia.org/wiki/Sultan_Al-Ghanam
# Already collected!
#
# https://en.wikipedia.org/wiki/Saud_Abdulhamid
# Already collected!
#
# https://en.wikipedia.org/wiki/Abdulelah_Al-Amri
# Already collected!
#
# https://en.wikipedia.org/wiki/Hassan_Tambakti
# Already collected!
#
# https://en.wikipedia.org/wiki/Abdullah_Madu
# Already collected!
#
# https://en.wikipedia.org/wiki/Salem_Al-Dawsari
# Already collected!
#
# https://en.wikipedia.org/wiki/Salman_Al-Faraj
# Already collected!
#
# https://en.wikipedia.org/wiki/Nawaf_Al-Abed
# Already collected!
#
# https://en.wikipedia.org/wiki/Abdullah_Otayf
# Already collected!
#
# https://en.wikipedia.org/wiki/Hattan_Bahebri
# Already collected!
#
# https://en.wikipedia.org/wiki/Mohamed_Kanno
# Already collected!
#
# https://en.wikipedia.org/wiki/Abdulellah_Al-Malki
# Already collected!
#
# https://en.wikipedia.org/wiki/Sami_Al-Najei
# Already collected!
#
# https://en.wikipedia.org/wiki/Ali_Al-Hassan
# Already collected!
#
# https://en.wikipedia.org/wiki/Nasser_Al-Dawsari
# Already collected!
#
# https://en.wikipedia.org/wiki/Riyadh_Sharahili
# Already collected!
#
# https://en.wikipedia.org/wiki/Abdulrahman_Al-Aboud
# Already collected!
#
# https://en.wikipedia.org/wiki/Firas_Al-Buraikan
# Already collected!
#
# https://en.wikipedia.org/wiki/Saleh_Al-Shehri
# Already collected!
#
# https://en.wikipedia.org/wiki/Haitham_Asiri
# Already collected!
#
# https://en.wikipedia.org/wiki/Mathew_Ryan
# Already collected!
#
# https://en.wikipedia.org/wiki/Milo%C5%A1_Degenek
# Already collected!
#
# https://en.wikipedia.org/wiki/Nathaniel_Atkinson
# Already collected!
#
# https://en.wikipedia.org/wiki/Kye_Rowles
# Already collected!
#
# https://en.wikipedia.org/wiki/Fran_Kara%C4%8Di%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Martin_Boyle
# Already collected!
#
# https://en.wikipedia.org/wiki/Mathew_Leckie
# Already collected!
#
# https://en.wikipedia.org/wiki/Bailey_Wright
# Already collected!
#
# https://en.wikipedia.org/wiki/Jamie_Maclaren
# Already collected!
#
# https://en.wikipedia.org/wiki/Ajdin_Hrustic
# Already collected!
#
# https://en.wikipedia.org/wiki/Awer_Mabil
# Already collected!
#
# https://en.wikipedia.org/wiki/Andrew_Redmayne
# Already collected!
#
# https://en.wikipedia.org/wiki/Aaron_Mooy
# Already collected!
#
# https://en.wikipedia.org/wiki/Riley_McGree
# Already collected!
#
# https://en.wikipedia.org/wiki/Mitchell_Duke
# Already collected!
#
# https://en.wikipedia.org/wiki/Aziz_Behich
# Already collected!
#
# https://en.wikipedia.org/wiki/Cameron_Devlin
# Already collected!
#
# https://en.wikipedia.org/wiki/Danny_Vukovic
# Already collected!
#
# https://en.wikipedia.org/wiki/Harry_Souttar
# Already collected!
#
# https://en.wikipedia.org/wiki/Thomas_Deng
# Already collected!
#
# https://en.wikipedia.org/wiki/Garang_Kuol
# Already collected!
#
# https://en.wikipedia.org/wiki/Jackson_Irvine
# Already collected!
#
# https://en.wikipedia.org/wiki/Craig_Goodwin
# Already collected!
#
# https://en.wikipedia.org/wiki/Joel_King
# Already collected!
#
# https://en.wikipedia.org/wiki/Jason_Cummings
# Already collected!
#
# https://en.wikipedia.org/wiki/Keanu_Baccus
# Already collected!
#
# https://en.wikipedia.org/wiki/Kasper_Schmeichel
# Already collected!
#
# https://en.wikipedia.org/wiki/Frederik_R%C3%B8nnow
# Already collected!
#
# https://en.wikipedia.org/wiki/Oliver_Christensen
# Already collected!
#
# https://en.wikipedia.org/wiki/Simon_Kj%C3%A6r
# Already collected!
#
# https://en.wikipedia.org/wiki/Andreas_Christensen
# Already collected!
#
# https://en.wikipedia.org/wiki/Jens_Stryger_Larsen
# Already collected!
#
# https://en.wikipedia.org/wiki/Daniel_Wass
# Already collected!
#
# https://en.wikipedia.org/wiki/Joakim_M%C3%A6hle
# Already collected!
#
# https://en.wikipedia.org/wiki/Joachim_Andersen_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Rasmus_Kristensen
# Already collected!
#
# https://en.wikipedia.org/wiki/Victor_Nelsson
# Already collected!
#
# https://en.wikipedia.org/wiki/Alexander_Bah
# Already collected!
#
# https://en.wikipedia.org/wiki/Christian_Eriksen
# Already collected!
#
# https://en.wikipedia.org/wiki/Thomas_Delaney
# Already collected!
#
# https://en.wikipedia.org/wiki/Pierre-Emile_H%C3%B8jbjerg
# Already collected!
#
# https://en.wikipedia.org/wiki/Mathias_Jensen
# Already collected!
#
# https://en.wikipedia.org/wiki/Christian_N%C3%B8rgaard
# Already collected!
#
# https://en.wikipedia.org/wiki/Yussuf_Poulsen
# Already collected!
#
# https://en.wikipedia.org/wiki/Martin_Braithwaite
# Already collected!
#
# https://en.wikipedia.org/wiki/Andreas_Cornelius
# Already collected!
#
# https://en.wikipedia.org/wiki/Kasper_Dolberg
# Already collected!
#
# https://en.wikipedia.org/wiki/Andreas_Skov_Olsen
# Already collected!
#
# https://en.wikipedia.org/wiki/Mikkel_Damsgaard
# Already collected!
#
# https://en.wikipedia.org/wiki/Jonas_Wind
# Already collected!
#
# https://en.wikipedia.org/wiki/Robert_Skov
# Already collected!
#
# https://en.wikipedia.org/wiki/Jesper_Lindstr%C3%B8m
# Already collected!
#
# https://en.wikipedia.org/wiki/Hugo_Lloris
# Already collected!
#
# https://en.wikipedia.org/wiki/Benjamin_Pavard
# Already collected!
#
# https://en.wikipedia.org/wiki/Axel_Disasi
# Already collected!
#
# https://en.wikipedia.org/wiki/Rapha%C3%ABl_Varane
# Already collected!
#
# https://en.wikipedia.org/wiki/Jules_Kound%C3%A9
# Already collected!
#
# https://en.wikipedia.org/wiki/Matteo_Guendouzi
# Already collected!
#
# https://en.wikipedia.org/wiki/Antoine_Griezmann
# Already collected!
#
# https://en.wikipedia.org/wiki/Aur%C3%A9lien_Tchouam%C3%A9ni
# Already collected!
#
# https://en.wikipedia.org/wiki/Olivier_Giroud
# Already collected!
#
# https://en.wikipedia.org/wiki/Kylian_Mbapp%C3%A9
# Already collected!
#
# https://en.wikipedia.org/wiki/Ousmane_Demb%C3%A9l%C3%A9
# Already collected!
#
# https://en.wikipedia.org/wiki/Christopher_Nkunku
# Already collected!
#
# https://en.wikipedia.org/wiki/Youssouf_Fofana_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Adrien_Rabiot
# Already collected!
#
# https://en.wikipedia.org/wiki/Jordan_Veretout
# Already collected!
#
# https://en.wikipedia.org/wiki/Steve_Mandanda
# Already collected!
#
# https://en.wikipedia.org/wiki/William_Saliba
# Already collected!
#
# https://en.wikipedia.org/wiki/Dayot_Upamecano
# Already collected!
#
# https://en.wikipedia.org/wiki/Karim_Benzema
# Already collected!
#
# https://en.wikipedia.org/wiki/Kingsley_Coman
# Already collected!
#
# https://en.wikipedia.org/wiki/Lucas_Hernandez
# Already collected!
#
# https://en.wikipedia.org/wiki/Theo_Hernandez
# Already collected!
#
# https://en.wikipedia.org/wiki/Alphonse_Areola
# Already collected!
#
# https://en.wikipedia.org/wiki/Ibrahima_Konat%C3%A9
# Already collected!
#
# https://en.wikipedia.org/wiki/Eduardo_Camavinga
# Already collected!
#
# https://en.wikipedia.org/wiki/Marcus_Thuram
# Already collected!
#
# https://en.wikipedia.org/wiki/Aymen_Mathlouthi
# Already collected!
#
# https://en.wikipedia.org/wiki/Bilel_Ifa
# Already collected!
#
# https://en.wikipedia.org/wiki/Montassar_Talbi
# Already collected!
#
# https://en.wikipedia.org/wiki/Yassine_Meriah
# Already collected!
#
# https://en.wikipedia.org/wiki/Nader_Ghandri
# Already collected!
#
# https://en.wikipedia.org/wiki/Dylan_Bronn
# Already collected!
#
# https://en.wikipedia.org/wiki/Youssef_Msakni
# Already collected!
#
# https://en.wikipedia.org/wiki/Hannibal_Mejbri
# Already collected!
#
# https://en.wikipedia.org/wiki/Issam_Jebali
# Already collected!
#
# https://en.wikipedia.org/wiki/Wahbi_Khazri
# Already collected!
#
# https://en.wikipedia.org/wiki/Taha_Yassine_Khenissi
# Already collected!
#
# https://en.wikipedia.org/wiki/Ali_Ma%C3%A2loul
# Already collected!
#
# https://en.wikipedia.org/wiki/Ferjani_Sassi
# Already collected!
#
# https://en.wikipedia.org/wiki/A%C3%AFssa_La%C3%AFdouni
# Already collected!
#
# https://en.wikipedia.org/wiki/Mohamed_Ali_Ben_Romdhane
# Already collected!
#
# https://en.wikipedia.org/wiki/Aymen_Dahmen
# Already collected!
#
# https://en.wikipedia.org/wiki/Ellyes_Skhiri
# Already collected!
#
# https://en.wikipedia.org/wiki/Ghailene_Chaalali
# Already collected!
#
# https://en.wikipedia.org/wiki/Seifeddine_Jaziri
# Already collected!
#
# https://en.wikipedia.org/wiki/Mohamed_Dr%C3%A4ger
# Already collected!
#
# https://en.wikipedia.org/wiki/Wajdi_Kechrida
# Already collected!
#
# https://en.wikipedia.org/wiki/Bechir_Ben_Sa%C3%AFd
# Already collected!
#
# https://en.wikipedia.org/wiki/Na%C3%AFm_Sliti
# Already collected!
#
# https://en.wikipedia.org/wiki/Ali_Abdi_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Anis_Ben_Slimane
# Already collected!
#
# https://en.wikipedia.org/wiki/Mouez_Hassen
# Already collected!
#
# https://en.wikipedia.org/wiki/Keylor_Navas
# Already collected!
#
# https://en.wikipedia.org/wiki/Esteban_Alvarado
# Already collected!
#
# https://en.wikipedia.org/wiki/Patrick_Sequeira
# Already collected!
#
# https://en.wikipedia.org/wiki/Francisco_Calvo
# Already collected!
#
# https://en.wikipedia.org/wiki/Bryan_Oviedo
# Already collected!
#
# https://en.wikipedia.org/wiki/%C3%93scar_Duarte_(footballer,_born_1989)
# Already collected!
#
# https://en.wikipedia.org/wiki/Kendall_Waston
# Already collected!
#
# https://en.wikipedia.org/wiki/R%C3%B3nald_Matarrita
# Already collected!
#
# https://en.wikipedia.org/wiki/Keysher_Fuller
# Already collected!
#
# https://en.wikipedia.org/wiki/Juan_Pablo_Vargas
# Already collected!
#
# https://en.wikipedia.org/wiki/Carlos_Mart%C3%ADnez_(footballer,_born_1999)
# Already collected!
#
# https://en.wikipedia.org/wiki/Celso_Borges
# Already collected!
#
# https://en.wikipedia.org/wiki/Bryan_Ruiz
# Already collected!
#
# https://en.wikipedia.org/wiki/Yeltsin_Tejeda
# Already collected!
#
# https://en.wikipedia.org/wiki/Gerson_Torres
# Already collected!
#
# https://en.wikipedia.org/wiki/Jewison_Bennette
# Already collected!
#
# https://en.wikipedia.org/wiki/Daniel_Chac%C3%B3n_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Youstin_Salas
# Already collected!
#
# https://en.wikipedia.org/wiki/Roan_Wilson
# Already collected!
#
# https://en.wikipedia.org/wiki/Brandon_Aguilera
# Already collected!
#
# https://en.wikipedia.org/wiki/Douglas_L%C3%B3pez
# Already collected!
#
# https://en.wikipedia.org/wiki/Anthony_Hern%C3%A1ndez
# Already collected!
#
# https://en.wikipedia.org/wiki/%C3%81lvaro_Zamora
# Already collected!
#
# https://en.wikipedia.org/wiki/Joel_Campbell
# Already collected!
#
# https://en.wikipedia.org/wiki/Johan_Venegas
# Already collected!
#
# https://en.wikipedia.org/wiki/Anthony_Contreras
# Already collected!
#
# https://en.wikipedia.org/wiki/Manuel_Neuer
# Already collected!
#
# https://en.wikipedia.org/wiki/Antonio_R%C3%BCdiger
# Already collected!
#
# https://en.wikipedia.org/wiki/David_Raum
# Already collected!
#
# https://en.wikipedia.org/wiki/Matthias_Ginter
# Already collected!
#
# https://en.wikipedia.org/wiki/Thilo_Kehrer
# Already collected!
#
# https://en.wikipedia.org/wiki/Joshua_Kimmich
# Already collected!
#
# https://en.wikipedia.org/wiki/Kai_Havertz
# Already collected!
#
# https://en.wikipedia.org/wiki/Leon_Goretzka
# Already collected!
#
# https://en.wikipedia.org/wiki/Niclas_F%C3%BCllkrug
# Already collected!
#
# https://en.wikipedia.org/wiki/Serge_Gnabry
# Already collected!
#
# https://en.wikipedia.org/wiki/Mario_G%C3%B6tze
# Already collected!
#
# https://en.wikipedia.org/wiki/Kevin_Trapp
# Already collected!
#
# https://en.wikipedia.org/wiki/Thomas_M%C3%BCller
# Already collected!
#
# https://en.wikipedia.org/wiki/Jamal_Musiala
# Already collected!
#
# https://en.wikipedia.org/wiki/Niklas_S%C3%BCle
# Already collected!
#
# https://en.wikipedia.org/wiki/Lukas_Klostermann
# Already collected!
#
# https://en.wikipedia.org/wiki/Julian_Brandt
# Already collected!
#
# https://en.wikipedia.org/wiki/Jonas_Hofmann
# Already collected!
#
# https://en.wikipedia.org/wiki/Leroy_San%C3%A9
# Already collected!
#
# https://en.wikipedia.org/wiki/Christian_G%C3%BCnter
# Already collected!
#
# https://en.wikipedia.org/wiki/%C4%B0lkay_G%C3%BCndo%C4%9Fan
# Already collected!
#
# https://en.wikipedia.org/wiki/Marc-Andr%C3%A9_ter_Stegen
# Already collected!
#
# https://en.wikipedia.org/wiki/Nico_Schlotterbeck
# Already collected!
#
# https://en.wikipedia.org/wiki/Karim_Adeyemi
# Already collected!
#
# https://en.wikipedia.org/wiki/Armel_Bella-Kotchap
# Already collected!
#
# https://en.wikipedia.org/wiki/Youssoufa_Moukoko
# Already collected!
#
# https://en.wikipedia.org/wiki/Eiji_Kawashima
# Already collected!
#
# https://en.wikipedia.org/wiki/Miki_Yamane
# Already collected!
#
# https://en.wikipedia.org/wiki/Shogo_Taniguchi
# Already collected!
#
# https://en.wikipedia.org/wiki/Ko_Itakura
# Already collected!
#
# https://en.wikipedia.org/wiki/Yuto_Nagatomo
# Already collected!
#
# https://en.wikipedia.org/wiki/Wataru_Endo
# Already collected!
#
# https://en.wikipedia.org/wiki/Gaku_Shibasaki
# Already collected!
#
# https://en.wikipedia.org/wiki/Ritsu_D%C5%8Dan
# Already collected!
#
# https://en.wikipedia.org/wiki/Kaoru_Mitoma
# Already collected!
#
# https://en.wikipedia.org/wiki/Takumi_Minamino
# Already collected!
#
# https://en.wikipedia.org/wiki/Takefusa_Kubo
# Already collected!
#
# https://en.wikipedia.org/wiki/Sh%C5%ABichi_Gonda
# Already collected!
#
# https://en.wikipedia.org/wiki/Hidemasa_Morita
# Already collected!
#
# https://en.wikipedia.org/wiki/Junya_Ito_(footballer,_born_1993)
# Already collected!
#
# https://en.wikipedia.org/wiki/Daichi_Kamada
# Already collected!
#
# https://en.wikipedia.org/wiki/Takehiro_Tomiyasu
# Already collected!
#
# https://en.wikipedia.org/wiki/Ao_Tanaka
# Already collected!
#
# https://en.wikipedia.org/wiki/Takuma_Asano
# Already collected!
#
# https://en.wikipedia.org/wiki/Hiroki_Sakai
# Already collected!
#
# https://en.wikipedia.org/wiki/Shuto_Machino
# Already collected!
#
# https://en.wikipedia.org/wiki/Ayase_Ueda
# Already collected!
#
# https://en.wikipedia.org/wiki/Maya_Yoshida
# Already collected!
#
# https://en.wikipedia.org/wiki/Daniel_Schmidt_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Yuki_Soma
# Already collected!
#
# https://en.wikipedia.org/wiki/Daizen_Maeda
# Already collected!
#
# https://en.wikipedia.org/wiki/Hiroki_Ito_(footballer,_born_1999)
# Already collected!
#
# https://en.wikipedia.org/wiki/Robert_S%C3%A1nchez
# Already collected!
#
# https://en.wikipedia.org/wiki/C%C3%A9sar_Azpilicueta
# Already collected!
#
# https://en.wikipedia.org/wiki/Eric_Garc%C3%ADa_(footballer,_born_2001)
# Already collected!
#
# https://en.wikipedia.org/wiki/Pau_Torres
# Already collected!
#
# https://en.wikipedia.org/wiki/Sergio_Busquets
# Already collected!
#
# https://en.wikipedia.org/wiki/Marcos_Llorente
# Already collected!
#
# https://en.wikipedia.org/wiki/%C3%81lvaro_Morata
# Already collected!
#
# https://en.wikipedia.org/wiki/Koke_(footballer,_born_1992)
# Already collected!
#
# https://en.wikipedia.org/wiki/Gavi_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Marco_Asensio
# Already collected!
#
# https://en.wikipedia.org/wiki/Ferran_Torres
# Already collected!
#
# https://en.wikipedia.org/wiki/Nico_Williams
# Already collected!
#
# https://en.wikipedia.org/wiki/David_Raya
# Already collected!
#
# https://en.wikipedia.org/wiki/Jos%C3%A9_Gay%C3%A0
# Already collected!
#
# https://en.wikipedia.org/wiki/Hugo_Guillam%C3%B3n
# Already collected!
#
# https://en.wikipedia.org/wiki/Rodri_(footballer,_born_1996)
# Already collected!
#
# https://en.wikipedia.org/wiki/Yeremy_Pino
# Already collected!
#
# https://en.wikipedia.org/wiki/Jordi_Alba
# Already collected!
#
# https://en.wikipedia.org/wiki/Carlos_Soler_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Dani_Carvajal
# Already collected!
#
# https://en.wikipedia.org/wiki/Dani_Olmo
# Already collected!
#
# https://en.wikipedia.org/wiki/Pablo_Sarabia
# Already collected!
#
# https://en.wikipedia.org/wiki/Unai_Sim%C3%B3n
# Already collected!
#
# https://en.wikipedia.org/wiki/Aymeric_Laporte
# Already collected!
#
# https://en.wikipedia.org/wiki/Ansu_Fati
# Already collected!
#
# https://en.wikipedia.org/wiki/Pedri
# Already collected!
#
# https://en.wikipedia.org/wiki/Thibaut_Courtois
# Already collected!
#
# https://en.wikipedia.org/wiki/Simon_Mignolet
# Already collected!
#
# https://en.wikipedia.org/wiki/Koen_Casteels
# Already collected!
#
# https://en.wikipedia.org/wiki/Jan_Vertonghen
# Already collected!
#
# https://en.wikipedia.org/wiki/Toby_Alderweireld
# Already collected!
#
# https://en.wikipedia.org/wiki/Thomas_Meunier
# Already collected!
#
# https://en.wikipedia.org/wiki/Timothy_Castagne
# Already collected!
#
# https://en.wikipedia.org/wiki/Arthur_Theate
# Already collected!
#
# https://en.wikipedia.org/wiki/Zeno_Debast
# Already collected!
#
# https://en.wikipedia.org/wiki/Wout_Faes
# Already collected!
#
# https://en.wikipedia.org/wiki/Axel_Witsel
# Already collected!
#
# https://en.wikipedia.org/wiki/Kevin_De_Bruyne
# Already collected!
#
# https://en.wikipedia.org/wiki/Yannick_Carrasco
# Already collected!
#
# https://en.wikipedia.org/wiki/Youri_Tielemans
# Already collected!
#
# https://en.wikipedia.org/wiki/Leander_Dendoncker
# Already collected!
#
# https://en.wikipedia.org/wiki/Hans_Vanaken
# Already collected!
#
# https://en.wikipedia.org/wiki/Leandro_Trossard
# Already collected!
#
# https://en.wikipedia.org/wiki/Charles_De_Ketelaere
# Already collected!
#
# https://en.wikipedia.org/wiki/Amadou_Onana
# Already collected!
#
# https://en.wikipedia.org/wiki/Eden_Hazard
# Already collected!
#
# https://en.wikipedia.org/wiki/Dries_Mertens
# Already collected!
#
# https://en.wikipedia.org/wiki/Romelu_Lukaku
# Already collected!
#
# https://en.wikipedia.org/wiki/Michy_Batshuayi
# Already collected!
#
# https://en.wikipedia.org/wiki/Thorgan_Hazard
# Already collected!
#
# https://en.wikipedia.org/wiki/J%C3%A9r%C3%A9my_Doku
# Already collected!
#
# https://en.wikipedia.org/wiki/Lo%C3%AFs_Openda
# Already collected!
#
# https://en.wikipedia.org/wiki/Dayne_St._Clair
# Already collected!
#
# https://en.wikipedia.org/wiki/Alistair_Johnston
# Already collected!
#
# https://en.wikipedia.org/wiki/Sam_Adekugbe
# Already collected!
#
# https://en.wikipedia.org/wiki/Kamal_Miller
# Already collected!
#
# https://en.wikipedia.org/wiki/Steven_Vit%C3%B3ria
# Already collected!
#
# https://en.wikipedia.org/wiki/Samuel_Piette
# Already collected!
#
# https://en.wikipedia.org/wiki/Stephen_Eust%C3%A1quio
# Already collected!
#
# https://en.wikipedia.org/wiki/Liam_Fraser
# Already collected!
#
# https://en.wikipedia.org/wiki/Lucas_Cavallini
# Already collected!
#
# https://en.wikipedia.org/wiki/Junior_Hoilett
# Already collected!
#
# https://en.wikipedia.org/wiki/Tajon_Buchanan
# Already collected!
#
# https://en.wikipedia.org/wiki/Ik%C3%A9_Ugbo
# Already collected!
#
# https://en.wikipedia.org/wiki/Atiba_Hutchinson
# Already collected!
#
# https://en.wikipedia.org/wiki/Mark-Anthony_Kaye
# Already collected!
#
# https://en.wikipedia.org/wiki/Isma%C3%ABl_Kon%C3%A9_(soccer,_born_2002)
# Already collected!
#
# https://en.wikipedia.org/wiki/James_Pantemis
# Already collected!
#
# https://en.wikipedia.org/wiki/Cyle_Larin
# Already collected!
#
# https://en.wikipedia.org/wiki/Milan_Borjan
# Already collected!
#
# https://en.wikipedia.org/wiki/Alphonso_Davies
# Already collected!
#
# https://en.wikipedia.org/wiki/Jonathan_David
# Already collected!
#
# https://en.wikipedia.org/wiki/Jonathan_Osorio
# Already collected!
#
# https://en.wikipedia.org/wiki/Richie_Laryea
# Already collected!
#
# https://en.wikipedia.org/wiki/Liam_Millar
# Already collected!
#
# https://en.wikipedia.org/wiki/David_Wotherspoon_(footballer,_born_1990)
# Already collected!
#
# https://en.wikipedia.org/wiki/Derek_Cornelius
# Already collected!
#
# https://en.wikipedia.org/wiki/Joel_Waterman
# Already collected!
#
# https://en.wikipedia.org/wiki/Dominik_Livakovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Josip_Stani%C5%A1i%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Borna_Bari%C5%A1i%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Ivan_Peri%C5%A1i%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Martin_Erli%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Dejan_Lovren
# Already collected!
#
# https://en.wikipedia.org/wiki/Lovro_Majer
# Already collected!
#
# https://en.wikipedia.org/wiki/Mateo_Kova%C4%8Di%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Andrej_Kramari%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Luka_Modri%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Marcelo_Brozovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Ivo_Grbi%C4%87_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Nikola_Vla%C5%A1i%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Marko_Livaja
# Already collected!
#
# https://en.wikipedia.org/wiki/Mario_Pa%C5%A1ali%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Bruno_Petkovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Ante_Budimir
# Already collected!
#
# https://en.wikipedia.org/wiki/Mislav_Or%C5%A1i%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Borna_Sosa
# Already collected!
#
# https://en.wikipedia.org/wiki/Jo%C5%A1ko_Gvardiol
# Already collected!
#
# https://en.wikipedia.org/wiki/Domagoj_Vida
# Already collected!
#
# https://en.wikipedia.org/wiki/Josip_Juranovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Ivica_Ivu%C5%A1i%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Josip_%C5%A0utalo
# Already collected!
#
# https://en.wikipedia.org/wiki/Luka_Su%C4%8Di%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Kristijan_Jaki%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Yassine_Bounou
# Already collected!
#
# https://en.wikipedia.org/wiki/Munir_Mohamedi
# Already collected!
#
# https://en.wikipedia.org/wiki/Ahmed_Reda_Tagnaouti
# Already collected!
#
# https://en.wikipedia.org/wiki/Romain_Sa%C3%AFss
# Already collected!
#
# https://en.wikipedia.org/wiki/Achraf_Hakimi
# Already collected!
#
# https://en.wikipedia.org/wiki/Nayef_Aguerd
# Already collected!
#
# https://en.wikipedia.org/wiki/Noussair_Mazraoui
# Already collected!
#
# https://en.wikipedia.org/wiki/Jawad_El_Yamiq
# Already collected!
#
# https://en.wikipedia.org/wiki/Achraf_Dari
# Already collected!
#
# https://en.wikipedia.org/wiki/Badr_Benoun
# Already collected!
#
# https://en.wikipedia.org/wiki/Yahia_Attiyat_Allah
# Already collected!
#
# https://en.wikipedia.org/wiki/Sofyan_Amrabat
# Already collected!
#
# https://en.wikipedia.org/wiki/Selim_Amallah
# Already collected!
#
# https://en.wikipedia.org/wiki/Amine_Harit
# Already collected!
#
# https://en.wikipedia.org/wiki/Ilias_Chair
# Already collected!
#
# https://en.wikipedia.org/wiki/Azzedine_Ounahi
# Already collected!
#
# https://en.wikipedia.org/wiki/Yahya_Jabrane
# Already collected!
#
# https://en.wikipedia.org/wiki/Abdelhamid_Sabiri
# Already collected!
#
# https://en.wikipedia.org/wiki/Bilal_El_Khannous
# Already collected!
#
# https://en.wikipedia.org/wiki/Youssef_En-Nesyri
# Already collected!
#
# https://en.wikipedia.org/wiki/Hakim_Ziyech
# Already collected!
#
# https://en.wikipedia.org/wiki/Sofiane_Boufal
# Already collected!
#
# https://en.wikipedia.org/wiki/Abderrazak_Hamdallah
# Already collected!
#
# https://en.wikipedia.org/wiki/Zakaria_Aboukhlal
# Already collected!
#
# https://en.wikipedia.org/wiki/Abde_Ezzalzouli
# Already collected!
#
# https://en.wikipedia.org/wiki/Walid_Cheddira
# Already collected!
#
# https://en.wikipedia.org/wiki/Alisson
# Already collected!
#
# https://en.wikipedia.org/wiki/Danilo_(footballer,_born_July_1991)
# Already collected!
#
# https://en.wikipedia.org/wiki/Thiago_Silva
# Already collected!
#
# https://en.wikipedia.org/wiki/Marquinhos
# Already collected!
#
# https://en.wikipedia.org/wiki/Casemiro
# Already collected!
#
# https://en.wikipedia.org/wiki/Alex_Sandro
# Already collected!
#
# https://en.wikipedia.org/wiki/Lucas_Paquet%C3%A1
# Already collected!
#
# https://en.wikipedia.org/wiki/Fred_(footballer,_born_1993)
# Already collected!
#
# https://en.wikipedia.org/wiki/Richarlison
# Already collected!
#
# https://en.wikipedia.org/wiki/Neymar
# Already collected!
#
# https://en.wikipedia.org/wiki/Raphinha
# Already collected!
#
# https://en.wikipedia.org/wiki/Weverton_(footballer,_born_1987)
# Already collected!
#
# https://en.wikipedia.org/wiki/Dani_Alves
# Already collected!
#
# https://en.wikipedia.org/wiki/%C3%89der_Milit%C3%A3o
# Already collected!
#
# https://en.wikipedia.org/wiki/Fabinho_(footballer,_born_1993)
# Already collected!
#
# https://en.wikipedia.org/wiki/Alex_Telles
# Already collected!
#
# https://en.wikipedia.org/wiki/Bruno_Guimar%C3%A3es
# Already collected!
#
# https://en.wikipedia.org/wiki/Gabriel_Jesus
# Already collected!
#
# https://en.wikipedia.org/wiki/Antony_(footballer,_born_2000)
# Already collected!
#
# https://en.wikipedia.org/wiki/Vin%C3%ADcius_J%C3%BAnior
# Already collected!
#
# https://en.wikipedia.org/wiki/Rodrygo
# Already collected!
#
# https://en.wikipedia.org/wiki/%C3%89verton_Ribeiro
# Already collected!
#
# https://en.wikipedia.org/wiki/Ederson_(footballer,_born_1993)
# Already collected!
#
# https://en.wikipedia.org/wiki/Gleison_Bremer
# Already collected!
#
# https://en.wikipedia.org/wiki/Pedro_(footballer,_born_1997)
# Already collected!
#
# https://en.wikipedia.org/wiki/Gabriel_Martinelli
# Already collected!
#
# https://en.wikipedia.org/wiki/Andr%C3%A9_Onana
# Already collected!
#
# https://en.wikipedia.org/wiki/Devis_Epassy
# Already collected!
#
# https://en.wikipedia.org/wiki/Simon_Ngapandouetnbu
# Already collected!
#
# https://en.wikipedia.org/wiki/Nicolas_Nkoulou
# Already collected!
#
# https://en.wikipedia.org/wiki/Collins_Fai
# Already collected!
#
# https://en.wikipedia.org/wiki/Nouhou_Tolo
# Already collected!
#
# https://en.wikipedia.org/wiki/Jean-Charles_Castelletto
# Already collected!
#
# https://en.wikipedia.org/wiki/Olivier_Mbaizo
# Already collected!
#
# https://en.wikipedia.org/wiki/Enzo_Ebosse
# Already collected!
#
# https://en.wikipedia.org/wiki/Christopher_Wooh
# Already collected!
#
# https://en.wikipedia.org/wiki/Andr%C3%A9-Frank_Zambo_Anguissa
# Already collected!
#
# https://en.wikipedia.org/wiki/Pierre_Kunde
# Already collected!
#
# https://en.wikipedia.org/wiki/Samuel_Gouet
# Already collected!
#
# https://en.wikipedia.org/wiki/Martin_Hongla
# Already collected!
#
# https://en.wikipedia.org/wiki/Ga%C3%ABl_Ondoua
# Already collected!
#
# https://en.wikipedia.org/wiki/Olivier_Ntcham
# Already collected!
#
# https://en.wikipedia.org/wiki/Jerome_Ngom_Mbekeli
# Already collected!
#
# https://en.wikipedia.org/wiki/Vincent_Aboubakar
# Already collected!
#
# https://en.wikipedia.org/wiki/Eric_Maxim_Choupo-Moting
# Already collected!
#
# https://en.wikipedia.org/wiki/Karl_Toko_Ekambi
# Already collected!
#
# https://en.wikipedia.org/wiki/Christian_Bassogog
# Already collected!
#
# https://en.wikipedia.org/wiki/Moumi_Ngamaleu
# Already collected!
#
# https://en.wikipedia.org/wiki/Jean-Pierre_Nsame
# Already collected!
#
# https://en.wikipedia.org/wiki/Bryan_Mbeumo
# Already collected!
#
# https://en.wikipedia.org/wiki/Georges-K%C3%A9vin_Nkoudou
# Already collected!
#
# https://en.wikipedia.org/wiki/Souaibou_Marou
# Already collected!
#
# https://en.wikipedia.org/wiki/Predrag_Rajkovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Marko_Dmitrovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Vanja_Milinkovi%C4%87-Savi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Nikola_Milenkovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Stefan_Mitrovi%C4%87_(footballer,_born_1990)
# Already collected!
#
# https://en.wikipedia.org/wiki/Strahinja_Pavlovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Milo%C5%A1_Veljkovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Filip_Mladenovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Sr%C4%91an_Babi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Strahinja_Erakovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Du%C5%A1an_Tadi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Filip_Kosti%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Nemanja_Gudelj
# Already collected!
#
# https://en.wikipedia.org/wiki/Nemanja_Maksimovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Nemanja_Radonji%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Filip_%C4%90uri%C4%8Di%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Sergej_Milinkovi%C4%87-Savi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Sa%C5%A1a_Luki%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Andrija_%C5%BDivkovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Darko_Lazovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Marko_Gruji%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Uro%C5%A1_Ra%C4%8Di%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Ivan_Ili%C4%87_(footballer,_born_2001)
# Already collected!
#
# https://en.wikipedia.org/wiki/Aleksandar_Mitrovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Luka_Jovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Du%C5%A1an_Vlahovi%C4%87
# Already collected!
#
# https://en.wikipedia.org/wiki/Yann_Sommer
# Already collected!
#
# https://en.wikipedia.org/wiki/Jonas_Omlin
# Already collected!
#
# https://en.wikipedia.org/wiki/Gregor_Kobel
# Already collected!
#
# https://en.wikipedia.org/wiki/Philipp_K%C3%B6hn
# Already collected!
#
# https://en.wikipedia.org/wiki/Ricardo_Rodriguez_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Fabian_Sch%C3%A4r
# Already collected!
#
# https://en.wikipedia.org/wiki/Manuel_Akanji
# Already collected!
#
# https://en.wikipedia.org/wiki/Nico_Elvedi
# Already collected!
#
# https://en.wikipedia.org/wiki/Silvan_Widmer
# Already collected!
#
# https://en.wikipedia.org/wiki/Eray_C%C3%B6mert
# Already collected!
#
# https://en.wikipedia.org/wiki/Xherdan_Shaqiri
# Already collected!
#
# https://en.wikipedia.org/wiki/Granit_Xhaka
# Already collected!
#
# https://en.wikipedia.org/wiki/Remo_Freuler
# Already collected!
#
# https://en.wikipedia.org/wiki/Denis_Zakaria
# Already collected!
#
# https://en.wikipedia.org/wiki/Djibril_Sow
# Already collected!
#
# https://en.wikipedia.org/wiki/Renato_Steffen
# Already collected!
#
# https://en.wikipedia.org/wiki/Edimilson_Fernandes
# Already collected!
#
# https://en.wikipedia.org/wiki/Fabian_Frei
# Already collected!
#
# https://en.wikipedia.org/wiki/Michel_Aebischer
# Already collected!
#
# https://en.wikipedia.org/wiki/Ardon_Jashari
# Already collected!
#
# https://en.wikipedia.org/wiki/Fabian_Rieder
# Already collected!
#
# https://en.wikipedia.org/wiki/Haris_Seferovic
# Already collected!
#
# https://en.wikipedia.org/wiki/Breel_Embolo
# Already collected!
#
# https://en.wikipedia.org/wiki/Ruben_Vargas
# Already collected!
#
# https://en.wikipedia.org/wiki/Christian_Fassnacht
# Already collected!
#
# https://en.wikipedia.org/wiki/Noah_Okafor
# Already collected!
#
# https://en.wikipedia.org/wiki/Lawrence_Ati-Zigi
# Already collected!
#
# https://en.wikipedia.org/wiki/Abdul_Manaf_Nurudeen
# Already collected!
#
# https://en.wikipedia.org/wiki/Ibrahim_Danlad
# Already collected!
#
# https://en.wikipedia.org/wiki/Baba_Rahman
# Already collected!
#
# https://en.wikipedia.org/wiki/Daniel_Amartey
# Already collected!
#
# https://en.wikipedia.org/wiki/Alexander_Djiku
# Already collected!
#
# https://en.wikipedia.org/wiki/Joseph_Aidoo_(Ghanaian_footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Gideon_Mensah_(footballer,_born_1998)
# Already collected!
#
# https://en.wikipedia.org/wiki/Denis_Odoi
# Already collected!
#
# https://en.wikipedia.org/wiki/Alidu_Seidu
# Already collected!
#
# https://en.wikipedia.org/wiki/Mohammed_Salisu
# Already collected!
#
# https://en.wikipedia.org/wiki/Tariq_Lamptey
# Already collected!
#
# https://en.wikipedia.org/wiki/Andr%C3%A9_Ayew
# Already collected!
#
# https://en.wikipedia.org/wiki/Thomas_Partey
# Already collected!
#
# https://en.wikipedia.org/wiki/Mohammed_Kudus
# Already collected!
#
# https://en.wikipedia.org/wiki/Daniel-Kofi_Kyereh
# Already collected!
#
# https://en.wikipedia.org/wiki/Elisha_Owusu
# Already collected!
#
# https://en.wikipedia.org/wiki/Daniel_Afriyie
# Already collected!
#
# https://en.wikipedia.org/wiki/Salis_Abdul_Samed
# Already collected!
#
# https://en.wikipedia.org/wiki/Jordan_Ayew
# Already collected!
#
# https://en.wikipedia.org/wiki/Kamaldeen_Sulemana
# Already collected!
#
# https://en.wikipedia.org/wiki/Abdul_Fatawu_Issahaku
# Already collected!
#
# https://en.wikipedia.org/wiki/Osman_Bukari
# Already collected!
#
# https://en.wikipedia.org/wiki/I%C3%B1aki_Williams
# Already collected!
#
# https://en.wikipedia.org/wiki/Antoine_Semenyo
# Already collected!
#
# https://en.wikipedia.org/wiki/Kamal_Sowah
# Already collected!
#
# https://en.wikipedia.org/wiki/Rui_Patr%C3%ADcio
# Already collected!
#
# https://en.wikipedia.org/wiki/Diogo_Costa
# Already collected!
#
# https://en.wikipedia.org/wiki/Jos%C3%A9_S%C3%A1
# Already collected!
#
# https://en.wikipedia.org/wiki/Pepe_(footballer,_born_1983)
# Already collected!
#
# https://en.wikipedia.org/wiki/Danilo_Pereira
# Already collected!
#
# https://en.wikipedia.org/wiki/Rapha%C3%ABl_Guerreiro
# Already collected!
#
# https://en.wikipedia.org/wiki/R%C3%BAben_Dias
# Already collected!
#
# https://en.wikipedia.org/wiki/Jo%C3%A3o_Cancelo
# Already collected!
#
# https://en.wikipedia.org/wiki/Nuno_Mendes_(footballer,_born_2002)
# Already collected!
#
# https://en.wikipedia.org/wiki/Diogo_Dalot
# Already collected!
#
# https://en.wikipedia.org/wiki/Ant%C3%B3nio_Silva_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/William_Carvalho
# Already collected!
#
# https://en.wikipedia.org/wiki/Bernardo_Silva
# Already collected!
#
# https://en.wikipedia.org/wiki/Jo%C3%A3o_M%C3%A1rio_(footballer,_born_January_1993)
# Already collected!
#
# https://en.wikipedia.org/wiki/Bruno_Fernandes
# Already collected!
#
# https://en.wikipedia.org/wiki/R%C3%BAben_Neves
# Already collected!
#
# https://en.wikipedia.org/wiki/Jo%C3%A3o_Palhinha
# Already collected!
#
# https://en.wikipedia.org/wiki/Matheus_Nunes
# Already collected!
#
# https://en.wikipedia.org/wiki/Ot%C3%A1vio_(footballer,_born_1995)
# Already collected!
#
# https://en.wikipedia.org/wiki/Vitinha_(footballer,_born_2000)
# Already collected!
#
# https://en.wikipedia.org/wiki/Cristiano_Ronaldo
# Already collected!
#
# https://en.wikipedia.org/wiki/Andr%C3%A9_Silva_(footballer,_born_1995)
# Already collected!
#
# https://en.wikipedia.org/wiki/Jo%C3%A3o_F%C3%A9lix
# Already collected!
#
# https://en.wikipedia.org/wiki/Rafael_Le%C3%A3o
# Already collected!
#
# https://en.wikipedia.org/wiki/Ricardo_Horta
# Already collected!
#
# https://en.wikipedia.org/wiki/Gon%C3%A7alo_Ramos
# Already collected!
#
# https://en.wikipedia.org/wiki/Kim_Seung-gyu
# Already collected!
#
# https://en.wikipedia.org/wiki/Jo_Hyeon-woo
# Already collected!
#
# https://en.wikipedia.org/wiki/Song_Bum-keun
# Already collected!
#
# https://en.wikipedia.org/wiki/Kim_Young-gwon
# Already collected!
#
# https://en.wikipedia.org/wiki/Kim_Jin-su
# Already collected!
#
# https://en.wikipedia.org/wiki/Hong_Chul
# Already collected!
#
# https://en.wikipedia.org/wiki/Kim_Min-jae_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Kwon_Kyung-won
# Already collected!
#
# https://en.wikipedia.org/wiki/Kim_Moon-hwan
# Already collected!
#
# https://en.wikipedia.org/wiki/Kim_Tae-hwan_(footballer,_born_1989)
# Already collected!
#
# https://en.wikipedia.org/wiki/Cho_Yu-min
# Already collected!
#
# https://en.wikipedia.org/wiki/Yoon_Jong-gyu
# Already collected!
#
# https://en.wikipedia.org/wiki/Son_Heung-min
# Already collected!
#
# https://en.wikipedia.org/wiki/Jung_Woo-young
# Already collected!
#
# https://en.wikipedia.org/wiki/Lee_Jae-sung_(footballer,_born_1992)
# Already collected!
#
# https://en.wikipedia.org/wiki/Hwang_Hee-chan
# Already collected!
#
# https://en.wikipedia.org/wiki/Kwon_Chang-hoon
# Already collected!
#
# https://en.wikipedia.org/wiki/Hwang_In-beom
# Already collected!
#
# https://en.wikipedia.org/wiki/Na_Sang-ho
# Already collected!
#
# https://en.wikipedia.org/wiki/Son_Jun-ho_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Paik_Seung-ho
# Already collected!
#
# https://en.wikipedia.org/wiki/Song_Min-kyu_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Jeong_Woo-yeong
# Already collected!
#
# https://en.wikipedia.org/wiki/Lee_Kang-in
# Already collected!
#
# https://en.wikipedia.org/wiki/Hwang_Ui-jo
# Already collected!
#
# https://en.wikipedia.org/wiki/Cho_Gue-sung
# Already collected!
#
# https://en.wikipedia.org/wiki/Fernando_Muslera
# Already collected!
#
# https://en.wikipedia.org/wiki/Sergio_Rochet
# Already collected!
#
# https://en.wikipedia.org/wiki/Sebasti%C3%A1n_Sosa
# Already collected!
#
# https://en.wikipedia.org/wiki/Diego_God%C3%ADn
# Already collected!
#
# https://en.wikipedia.org/wiki/Mart%C3%ADn_C%C3%A1ceres
# Already collected!
#
# https://en.wikipedia.org/wiki/Jos%C3%A9_Mar%C3%ADa_Gim%C3%A9nez
# Already collected!
#
# https://en.wikipedia.org/wiki/Sebasti%C3%A1n_Coates
# Already collected!
#
# https://en.wikipedia.org/wiki/Mat%C3%ADas_Vi%C3%B1a
# Already collected!
#
# https://en.wikipedia.org/wiki/Ronald_Ara%C3%BAjo
# Already collected!
#
# https://en.wikipedia.org/wiki/Guillermo_Varela
# Already collected!
#
# https://en.wikipedia.org/wiki/Math%C3%ADas_Olivera
# Already collected!
#
# https://en.wikipedia.org/wiki/Jos%C3%A9_Luis_Rodr%C3%ADguez_(footballer,_born_1997)
# Already collected!
#
# https://en.wikipedia.org/wiki/Mat%C3%ADas_Vecino
# Already collected!
#
# https://en.wikipedia.org/wiki/Rodrigo_Bentancur
# Already collected!
#
# https://en.wikipedia.org/wiki/Federico_Valverde
# Already collected!
#
# https://en.wikipedia.org/wiki/Giorgian_de_Arrascaeta
# Already collected!
#
# https://en.wikipedia.org/wiki/Lucas_Torreira
# Already collected!
#
# https://en.wikipedia.org/wiki/Nicol%C3%A1s_de_la_Cruz
# Already collected!
#
# https://en.wikipedia.org/wiki/Manuel_Ugarte_(footballer)
# Already collected!
#
# https://en.wikipedia.org/wiki/Luis_Su%C3%A1rez
# Already collected!
#
# https://en.wikipedia.org/wiki/Edinson_Cavani
# Already collected!
#
# https://en.wikipedia.org/wiki/Maxi_G%C3%B3mez
# Already collected!
#
# https://en.wikipedia.org/wiki/Darwin_N%C3%BA%C3%B1ez
# Already collected!
#
# https://en.wikipedia.org/wiki/Facundo_Torres
# Already collected!
#
# https://en.wikipedia.org/wiki/Facundo_Pellistri
# Already collected!
#
# https://en.wikipedia.org/wiki/Agust%C3%ADn_Canobbio
# Already collected!
#
# https://en.wikipedia.org/wiki/Alexander_Dom%C3%ADnguez
# Already collected!
#
# https://en.wikipedia.org/wiki/Hern%C3%A1n_Gal%C3%ADndez
# Already collected!
#
# https://en.wikipedia.org/wiki/Mois%C3%A9s_Ram%C3%ADrez
# Already collected!
#
# https://en.wikipedia.org/wiki/Robert_Arboleda
# Already collected!
#
# https://en.wikipedia.org/wiki/Xavier_Arreaga
# Already collected!
#
# https://en.wikipedia.org/wiki/Pervis_Estupi%C3%B1%C3%A1n
# Already collected!
#
# https://en.wikipedia.org/wiki/Piero_Hincapi%C3%A9
# Already collected!
#
# https://en.wikipedia.org/wiki/William_Pacho
# https://www.transfermarkt.com/dummy/profil/spieler/661171
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/661171/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/661171
#
# https://en.wikipedia.org/wiki/Diego_Palacios
# https://www.transfermarkt.com/dummy/profil/spieler/425567
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/425567/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/425567
#
# https://en.wikipedia.org/wiki/Jackson_Porozo
# https://www.transfermarkt.com/dummy/profil/spieler/491616
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/491616/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/491616
#
# https://en.wikipedia.org/wiki/%C3%81ngelo_Preciado
# https://www.transfermarkt.com/dummy/profil/spieler/450241
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/450241/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/450241
#
# https://en.wikipedia.org/wiki/F%C3%A9lix_Torres_(footballer,_born_1997)
# https://www.transfermarkt.com/dummy/profil/spieler/468174
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/468174/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/468174
#
# https://en.wikipedia.org/wiki/Mois%C3%A9s_Caicedo
# https://www.transfermarkt.com/dummy/profil/spieler/687626
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/687626/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/687626
#
# https://en.wikipedia.org/wiki/Jos%C3%A9_Cifuentes
# https://www.transfermarkt.com/dummy/profil/spieler/450211
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/450211/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/450211
#
# https://en.wikipedia.org/wiki/Alan_Franco_(footballer,_born_1998)
# https://www.transfermarkt.com/dummy/profil/spieler/400960
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/400960/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/400960
#
# https://en.wikipedia.org/wiki/Carlos_Gruezo_(footballer,_born_1995)
# https://www.transfermarkt.com/dummy/profil/spieler/189475
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/189475/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/189475
#
# https://en.wikipedia.org/wiki/%C3%81ngel_Mena
# https://www.transfermarkt.com/dummy/profil/spieler/123609
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/123609/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/123609
#
# https://en.wikipedia.org/wiki/Sebas_M%C3%A9ndez
# https://www.transfermarkt.com/dummy/profil/spieler/330682
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/330682/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/330682
#
# https://en.wikipedia.org/wiki/Gonzalo_Plata
# https://www.transfermarkt.com/dummy/profil/spieler/592735
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/592735/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/592735
#
# https://en.wikipedia.org/wiki/Kevin_Rodr%C3%ADguez
# https://www.transfermarkt.com/dummy/profil/spieler/684159
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/684159/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/684159
#
# https://en.wikipedia.org/wiki/Jeremy_Sarmiento
# https://www.transfermarkt.com/dummy/profil/spieler/568005
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/568005/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/568005
#
# https://en.wikipedia.org/wiki/Michael_Estrada
# https://www.transfermarkt.com/dummy/profil/spieler/265481
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/265481/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/265481
#
# https://en.wikipedia.org/wiki/Romario_Ibarra
# https://www.transfermarkt.com/dummy/profil/spieler/263605
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/263605/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/263605
#
# https://en.wikipedia.org/wiki/Ayrton_Preciado
# https://www.transfermarkt.com/dummy/profil/spieler/212310
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/212310/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/212310
#
# https://en.wikipedia.org/wiki/Djorkaeff_Reasco
# https://www.transfermarkt.com/dummy/profil/spieler/473346
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/473346/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/473346
#
# https://en.wikipedia.org/wiki/Enner_Valencia
# https://www.transfermarkt.com/dummy/profil/spieler/139503
# https://www.transfermarkt.com/dummy/leistungsdaten/spieler/139503/plus/0?saison=ges
# https://www.transfermarkt.com/dummy/leistungsdatenverein/spieler/139503
